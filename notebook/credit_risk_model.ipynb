# %% [markdown]
# <h1 align='center' style='color:blue'>Codebasics ML Course: Credit Risk Modeling Project</h1>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

pd.set_option('display.float_format', lambda x: '{:.2f}'.format(x))
np.set_printoptions(suppress=True)

# %% [markdown]
# ### Load Data

# %%
df_customers = pd.read_csv("Data_Resources/customers.csv")
df_loans = pd.read_csv("Data_Resources/loans.csv")
df_bureau = pd.read_csv("Data_Resources/bureau_data.csv")

# %%
df_customers.shape, df_loans.shape, df_bureau.shape
# Out:
# ((50000, 12), (50000, 15), (50000, 8))

# %%
df_customers.head(3)
# Out:
#   cust_id  age gender marital_status employment_status   income  \
# 0  C00001   44      M        Married     Self-Employed  2586000
# 1  C00002   38      M        Married          Salaried  1206000
# 2  C00003   46      F        Married     Self-Employed  2878000
#
#    number_of_dependants residence_type  years_at_current_address     city  \
# 0                     3          Owned                        27    Delhi
# 1                     3          Owned                         4  Chennai
# 2                     3          Owned                        24  Kolkata
#
#          state  zipcode
# 0        Delhi   110001
# 1   Tamil Nadu   600001
# 2  West Bengal   700001

# %%
df_loans.head(3)
# Out:
#   loan_id cust_id loan_purpose  loan_type  sanction_amount  loan_amount  \
# 0  L00001  C00001         Auto    Secured          3004000      2467000
# 1  L00002  C00002         Home    Secured          4161000      3883000
# 2  L00003  C00003     Personal  Unsecured          2401000      2170000
#
#    processing_fee     gst  net_disbursement  loan_tenure_months  \
# 0        49340.00  444060           1973600                  33
# 1        77660.00  698940           3106400                  30
# 2        43400.00  390600           1736000                  21
#
#    principal_outstanding  bank_balance_at_application disbursal_date  \
# 0                1630408                       873386     2019-07-24
# 1                 709309                       464100     2019-07-24
# 2                1562399                      1476042     2019-07-24
#
#   installment_start_dt  default
# 0           2019-08-10    False
# 1           2019-08-15    False
# 2           2019-08-21    False

# %%
df_bureau.head(3)
# Out:
#   cust_id  number_of_open_accounts  number_of_closed_accounts  \
# 0  C00001                        1                          1
# 1  C00002                        3                          1
# 2  C00003                        2                          1
#
#    total_loan_months  delinquent_months  total_dpd  enquiry_count  \
# 0                 42                  0          0              3
# 1                 96                 12         60              5
# 2                 82                 24        147              6
#
#    credit_utilization_ratio
# 0                         7
# 1                         4
# 2                        58

# %%
df = pd.merge(df_customers, df_loans, on='cust_id')
df.head(3)
# Out:
#   cust_id  age gender marital_status employment_status   income  \
# 0  C00001   44      M        Married     Self-Employed  2586000
# 1  C00002   38      M        Married          Salaried  1206000
# 2  C00003   46      F        Married     Self-Employed  2878000
#
#    number_of_dependants residence_type  years_at_current_address     city  \
# 0                     3          Owned                        27    Delhi
# 1                     3          Owned                         4  Chennai
# 2                     3          Owned                        24  Kolkata
#
#    ... loan_amount  processing_fee     gst net_disbursement  \
# 0  ...     2467000        49340.00  444060          1973600
# 1  ...     3883000        77660.00  698940          3106400
# 2  ...     2170000        43400.00  390600          1736000
#
#   loan_tenure_months  principal_outstanding  bank_balance_at_application  \
# 0                 33                1630408                       873386
# 1                 30                 709309                       464100
# 2                 21                1562399                      1476042
#
#    disbursal_date  installment_start_dt  default
# 0      2019-07-24            2019-08-10    False
# 1      2019-07-24            2019-08-15    False
# 2      2019-07-24            2019-08-21    False
#
# [3 rows x 26 columns]

# %%
df = pd.merge(df, df_bureau, on='cust_id')
df.head(3)
# Out:
#   cust_id  age gender marital_status employment_status   income  \
# 0  C00001   44      M        Married     Self-Employed  2586000
# 1  C00002   38      M        Married          Salaried  1206000
# 2  C00003   46      F        Married     Self-Employed  2878000
#
#    number_of_dependants residence_type  years_at_current_address     city  \
# 0                     3          Owned                        27    Delhi
# 1                     3          Owned                         4  Chennai
# 2                     3          Owned                        24  Kolkata
#
#    ... disbursal_date  installment_start_dt default number_of_open_accounts  \
# 0  ...     2019-07-24            2019-08-10   False                       1
# 1  ...     2019-07-24            2019-08-15   False                       3
# 2  ...     2019-07-24            2019-08-21   False                       2
#
#   number_of_closed_accounts  total_loan_months  delinquent_months  total_dpd  \
# 0                         1                 42                  0          0
# 1                         1                 96                 12         60
# 2                         1                 82                 24        147
#
#    enquiry_count  credit_utilization_ratio
# 0              3                         7
# 1              5                         4
# 2              6                        58
#
# [3 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   cust_id                      50000 non-null  object
#  1   age                          50000 non-null  int64
#  2   gender                       50000 non-null  object
#  3   marital_status               50000 non-null  object
#  4   employment_status            50000 non-null  object
#  5   income                       50000 non-null  int64
#  6   number_of_dependants         50000 non-null  int64
#  7   residence_type               49938 non-null  object
#  8   years_at_current_address     50000 non-null  int64
#  9   city                         50000 non-null  object
#  10  state                        50000 non-null  object
#  11  zipcode                      50000 non-null  int64
#  12  loan_id                      50000 non-null  object
#  13  loan_purpose                 50000 non-null  object
#  14  loan_type                    50000 non-null  object
#  15  sanction_amount              50000 non-null  int64
#  16  loan_amount                  50000 non-null  int64
#  17  processing_fee               50000 non-null  float64
#  18  gst                          50000 non-null  int64
#  19  net_disbursement             50000 non-null  int64
#  20  loan_tenure_months           50000 non-null  int64
#  21  principal_outstanding        50000 non-null  int64
#  22  bank_balance_at_application  50000 non-null  int64
#  23  disbursal_date               50000 non-null  object
#  24  installment_start_dt         50000 non-null  object
#  25  default                      50000 non-null  bool
#  26  number_of_open_accounts      50000 non-null  int64
#  27  number_of_closed_accounts    50000 non-null  int64
#  28  total_loan_months            50000 non-null  int64
#  29  delinquent_months            50000 non-null  int64
#  30  total_dpd                    50000 non-null  int64
#  31  enquiry_count                50000 non-null  int64
#  32  credit_utilization_ratio     50000 non-null  int64
# dtypes: bool(1), float64(1), int64(19), object(12)
# memory usage: 12.3+ MB

# %%
df['default'] = df['default'].astype(int)
df.default.value_counts()
# Out:
# default
# 0    45703
# 1     4297
# Name: count, dtype: int64

# %% [markdown]
# default is a target variable and we can see some class imbalance here. We will address it later on.

# %% [markdown]
# ### Train Test split

# %% [markdown]
# We perform train test split before doing EDA to prevent data leakage. We don't want test set (which is part of the entire dataset) to influence EDA or any decisions on feature engineering.

# %%
X = df.drop("default", axis="columns")
y = df['default']

X_train,X_test,y_train,y_test=train_test_split(X,y,stratify=y,test_size=0.25,random_state=42)

df_train = pd.concat([X_train, y_train], axis="columns")
df_test = pd.concat([X_test, y_test], axis="columns")

df_train.head(2)
# Out:
#       cust_id  age gender marital_status employment_status    income  \
# 12746  C12747   59      M        Married     Self-Employed  11327000
# 32495  C32496   44      F         Single          Salaried    715000
#
#        number_of_dependants residence_type  years_at_current_address  \
# 12746                     3          Owned                        30
# 32495                     0          Owned                        27
#
#             city  ... disbursal_date  installment_start_dt  \
# 12746  Hyderabad  ...     2020-10-31            2020-11-11
# 32495     Mumbai  ...     2022-10-22            2022-10-27
#
#       number_of_open_accounts number_of_closed_accounts total_loan_months  \
# 12746                       4                         2               152
# 32495                       3                         1               160
#
#        delinquent_months  total_dpd  enquiry_count  credit_utilization_ratio  \
# 12746                 20        118              4                        36
# 32495                 10         62              5                         5
#
#        default
# 12746        0
# 32495        0
#
# [2 rows x 33 columns]

# %% [markdown]
# <h3 align="center" style="color:blue">Data Cleaning</h3>

# %% [markdown]
# ### Handle Missing & Duplicate Values

# %%
df_train.shape
# Out:
# (37500, 33)

# %%
df_train.isna().sum()
# Out:
# cust_id                         0
# age                             0
# gender                          0
# marital_status                  0
# employment_status               0
# income                          0
# number_of_dependants            0
# residence_type                 47
# years_at_current_address        0
# city                            0
# state                           0
# zipcode                         0
# loan_id                         0
# loan_purpose                    0
# loan_type                       0
# sanction_amount                 0
# loan_amount                     0
# processing_fee                  0
# gst                             0
# net_disbursement                0
# loan_tenure_months              0
# principal_outstanding           0
# bank_balance_at_application     0
# disbursal_date                  0
# installment_start_dt            0
# number_of_open_accounts         0
# number_of_closed_accounts       0
# total_loan_months               0
# delinquent_months               0
# total_dpd                       0
# enquiry_count                   0
# credit_utilization_ratio        0
# default                         0
# dtype: int64

# %%
df_train.residence_type.unique()
# Out:
# array(['Owned', 'Mortgage', 'Rented', nan], dtype=object)

# %%
mode_residence = df_train.residence_type.mode()[0]
mode_residence
# Out:
# 'Owned'

# %%
df_train.residence_type.fillna(mode_residence, inplace=True)
df_test.residence_type.fillna(mode_residence, inplace=True)

df_train.residence_type.unique(), df_test.residence_type.unique()
# Out:
# /var/folders/hf/yt2vntbs2cs3zhkmcfyxz58w0000gn/T/ipykernel_45244/2805913581.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_train.residence_type.fillna(mode_residence, inplace=True)
# /var/folders/hf/yt2vntbs2cs3zhkmcfyxz58w0000gn/T/ipykernel_45244/2805913581.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_test.residence_type.fillna(mode_residence, inplace=True)
# (array(['Owned', 'Mortgage', 'Rented'], dtype=object),
#  array(['Owned', 'Mortgage', 'Rented'], dtype=object))

# %%
df_train.duplicated().sum()
# Out:
# 0

# %%
df_train.describe()
# Out:
#            age      income  number_of_dependants  years_at_current_address  \
# count 37500.00    37500.00              37500.00                  37500.00
# mean     39.54  2633326.16                  1.94                     16.00
# std       9.86  2623780.52                  1.54                      8.92
# min      18.00        0.00                  0.00                      1.00
# 25%      33.00   802000.00                  0.00                      8.00
# 50%      39.00  1885000.00                  2.00                     16.00
# 75%      46.00  3326250.00                  3.00                     24.00
# max      70.00 11999000.00                  5.00                     31.00
#
#         zipcode  sanction_amount  loan_amount  processing_fee        gst  \
# count  37500.00         37500.00     37500.00        37500.00   37500.00
# mean  418866.25       4699691.57   3996067.73        80290.68  719292.19
# std   169035.02       6257832.98   5371862.29       113128.14  966935.21
# min   110001.00             0.00         0.00            0.00       0.00
# 25%   302001.00       1142000.00    961000.00        19220.00  172980.00
# 50%   400001.00       2644000.00   2230000.00        44600.00  401400.00
# 75%   560001.00       5178000.00   4619000.00        92420.00  831420.00
# max   700001.00      52175000.00  47819000.00      5293543.52 8607420.00
#
#        net_disbursement  ...  principal_outstanding  \
# count          37500.00  ...               37500.00
# mean         3196854.19  ...             1333819.51
# std          4297489.83  ...             1213674.44
# min                0.00  ...                  -1.00
# 25%           768800.00  ...              422197.50
# 50%          1784000.00  ...              997427.50
# 75%          3695200.00  ...             1784879.00
# max         38255200.00  ...             5000000.00
#
#        bank_balance_at_application  number_of_open_accounts  \
# count                     37500.00                 37500.00
# mean                     986298.87                     2.50
# std                     1043145.01                     1.12
# min                           0.00                     1.00
# 25%                      287040.25                     1.00
# 50%                      665014.50                     3.00
# 75%                     1234062.75                     4.00
# max                     7846643.00                     4.00
#
#        number_of_closed_accounts  total_loan_months  delinquent_months  \
# count                   37500.00           37500.00           37500.00
# mean                        1.00              76.11               4.84
# std                         0.81              43.77               5.84
# min                         0.00               1.00               0.00
# 25%                         0.00              42.00               0.00
# 50%                         1.00              71.00               3.00
# 75%                         2.00             107.00               8.00
# max                         2.00             223.00              24.00
#
#        total_dpd  enquiry_count  credit_utilization_ratio  default
# count   37500.00       37500.00                  37500.00 37500.00
# mean       26.67           5.01                     43.42     0.09
# std        32.78           2.03                     29.39     0.28
# min         0.00           1.00                      0.00     0.00
# 25%         0.00           4.00                     18.00     0.00
# 50%        13.00           5.00                     39.00     0.00
# 75%        46.00           6.00                     67.00     0.00
# max       171.00           9.00                     99.00     1.00
#
# [8 rows x 21 columns]

# %%
df_train.columns
# Out:
# Index(['cust_id', 'age', 'gender', 'marital_status', 'employment_status',
#        'income', 'number_of_dependants', 'residence_type',
#        'years_at_current_address', 'city', 'state', 'zipcode', 'loan_id',
#        'loan_purpose', 'loan_type', 'sanction_amount', 'loan_amount',
#        'processing_fee', 'gst', 'net_disbursement', 'loan_tenure_months',
#        'principal_outstanding', 'bank_balance_at_application',
#        'disbursal_date', 'installment_start_dt', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'total_loan_months', 'delinquent_months',
#        'total_dpd', 'enquiry_count', 'credit_utilization_ratio', 'default'],
#       dtype='object')

# %%
columns_continuous = ['age', 'income', 'number_of_dependants', 'years_at_current_address', 
                      'sanction_amount', 'loan_amount', 'processing_fee', 'gst', 'net_disbursement', 
                      'loan_tenure_months','principal_outstanding', 'bank_balance_at_application',
                      'number_of_open_accounts','number_of_closed_accounts', 'total_loan_months', 'delinquent_months',
                       'total_dpd', 'enquiry_count', 'credit_utilization_ratio']

columns_categorical = ['gender', 'marital_status', 'employment_status', 'residence_type', 'city', 
                       'state', 'zipcode', 'loan_purpose', 'loan_type', 'default']

# %% [markdown]
# ### Box plot to visualize outliers

# %%
num_plots = len(columns_continuous)
num_cols = 4  # Number of plots per row
num_rows = (num_plots + num_cols - 1) // num_cols  # Calculate the number of rows needed

fig, axes = plt.subplots(num_rows, num_cols, figsize=(5 * num_cols, 5 * num_rows))  # Adjust the figure size as needed
axes = axes.flatten()  # Flatten the axes array for easier indexing

for i, col in enumerate(columns_continuous):
    sns.boxplot(x=df_train[col], ax=axes[i])
    axes[i].set_title(col)  # Set the title to the name of the variable

# If there are any empty plots (if the number of plots isn't a perfect multiple of num_cols), hide the axes
for j in range(i + 1, num_rows * num_cols):
    axes[j].axis('off')

plt.tight_layout()
plt.show()

# %%
num_plots = len(columns_continuous)
num_cols = 4  # Number of plots per row
num_rows = (num_plots + num_cols - 1) // num_cols  # Calculate the number of rows needed

fig, axes = plt.subplots(num_rows, num_cols, figsize=(5 * num_cols, 5 * num_rows))  # Adjust the figure size as needed
axes = axes.flatten()  # Flatten the axes array for easier indexing

for i, col in enumerate(columns_continuous):
    sns.histplot(df_train[col], ax=axes[i])
    axes[i].set_title(col)  # Set the title to the name of the variable

# If there are any empty plots (if the number of plots isn't a perfect multiple of num_cols), hide the axes
for j in range(i + 1, num_rows * num_cols):
    axes[j].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Outlier Removal: Processing Fee

# %%
df_train.processing_fee.describe()
# Out:
# count     37500.00
# mean      80290.68
# std      113128.14
# min           0.00
# 25%       19220.00
# 50%       44600.00
# 75%       92420.00
# max     5293543.52
# Name: processing_fee, dtype: float64

# %%
df_train[(df_train.processing_fee/df_train.loan_amount)>0.03][["loan_amount","processing_fee"]]
# Out:
#        loan_amount  processing_fee
# 23981      2234000      2669791.02
# 28174       966000      1214492.67
# 47089      1738000      1858964.77
# 29305      2616000      3036378.01
# 9898       3626000      5293543.52

# %%
df_train_1 = df_train[df_train.processing_fee/df_train.loan_amount<0.03].copy()
df_train_1.shape
# Out:
# (37488, 33)

# %%
df_test.residence_type.isna().sum()
# Out:
# 0

# %%
# Apply same step on test set
df_test = df_test[df_test.processing_fee/df_test.loan_amount<0.03].copy()
df_test.shape
# Out:
# (12497, 33)

# %%
# Use other business rules for data validation
# Rule 1: GST should not be more than 20%

df_train_1[(df_train_1.gst/df_train_1.loan_amount)>0.2].shape
# Out:
# (0, 33)

# %%
# Rule 2: Net disbursement should not be higher than loan_amount
df_train_1[df_train_1.net_disbursement>df_train_1.loan_amount].shape
# Out:
# (0, 33)

# %% [markdown]
# No rows found that breaks rule 1 and rule 2

# %% [markdown]
# ### Analyze Categorical Columns

# %%
columns_categorical
# Out:
# ['gender',
#  'marital_status',
#  'employment_status',
#  'residence_type',
#  'city',
#  'state',
#  'zipcode',
#  'loan_purpose',
#  'loan_type',
#  'default']

# %%
for col in columns_categorical:
    print(col, "-->", df_train_1[col].unique())
# Out:
# gender --> ['M' 'F']
# marital_status --> ['Married' 'Single']
# employment_status --> ['Self-Employed' 'Salaried']
# residence_type --> ['Owned' 'Mortgage' 'Rented']
# city --> ['Hyderabad' 'Mumbai' 'Chennai' 'Bangalore' 'Pune' 'Kolkata' 'Ahmedabad'
#  'Delhi' 'Lucknow' 'Jaipur']
# state --> ['Telangana' 'Maharashtra' 'Tamil Nadu' 'Karnataka' 'West Bengal'
#  'Gujarat' 'Delhi' 'Uttar Pradesh' 'Rajasthan']
# zipcode --> [500001 400001 600001 560001 411001 700001 380001 110001 226001 302001]
# loan_purpose --> ['Home' 'Education' 'Personal' 'Auto' 'Personaal']
# loan_type --> ['Secured' 'Unsecured']
# default --> [0 1]

# %% [markdown]
# ### Fix Errors in Loan Purpose Column

# %%
df_train_1['loan_purpose'] = df_train_1['loan_purpose'].replace('Personaal', 'Personal')
df_train_1['loan_purpose'].unique()
# Out:
# array(['Home', 'Education', 'Personal', 'Auto'], dtype=object)

# %%
df_test['loan_purpose'] = df_test['loan_purpose'].replace('Personaal', 'Personal')
df_test['loan_purpose'].unique()
# Out:
# array(['Home', 'Education', 'Auto', 'Personal'], dtype=object)

# %% [markdown]
# <h3 style="color:blue" align="center">Exploratory Data Analysis</h3>

# %%
columns_continuous
# Out:
# ['age',
#  'income',
#  'number_of_dependants',
#  'years_at_current_address',
#  'sanction_amount',
#  'loan_amount',
#  'processing_fee',
#  'gst',
#  'net_disbursement',
#  'loan_tenure_months',
#  'principal_outstanding',
#  'bank_balance_at_application',
#  'number_of_open_accounts',
#  'number_of_closed_accounts',
#  'total_loan_months',
#  'delinquent_months',
#  'total_dpd',
#  'enquiry_count',
#  'credit_utilization_ratio']

# %% [markdown]
# ### Age Column

# %%
df_train_1.groupby("default")['age'].describe()
# Out:
#            count  mean  std   min   25%   50%   75%   max
# default
# 0       34265.00 39.77 9.88 18.00 33.00 40.00 46.00 70.00
# 1        3223.00 37.12 9.29 18.00 31.00 37.00 44.00 70.00

# %% [markdown]
# **Insights**
#
# 1. Average age in the default group is little less (37.12) than the average (39.7) of the group that did not default
# 1. Variability (standard deviation) is mostly similar in both the groups
# 1. Both the groups have similar min and max ages

# %%
plt.figure(figsize=(8, 4))
sns.kdeplot(df_train_1['age'][df_train_1['default'] == 0], fill=True, label='default=0')
sns.kdeplot(df_train_1['age'][df_train_1['default'] == 1], fill=True, label='default=1')
plt.title(f"Age KDE Plot with Hue by default")
plt.legend()
plt.show()

# %% [markdown]
# **Insights**
#
# 1. Orange (defaulted) group is slightly shifted to left indicating that younger folks are more likely to default on their loans

# %% [markdown]
# ### KDE for all the Columns

# %%
plt.figure(figsize=(24, 20))  # Width, height in inches

for i, col in enumerate(columns_continuous):
    plt.subplot(6, 4, i+1)  # 1 row, 4 columns, ith subplot
    sns.kdeplot(df_train_1[col][df_train_1['default']==0], fill=True, label='default=0')
    sns.kdeplot(df_train_1[col][df_train_1['default']==1], fill=True, label='default=1')
    plt.title(col)        
    plt.xlabel('')
    
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insights**
#
# 1. In columns: loan_tenure_months, delinquent_months, total_dpd, credit_utilization, higher values indicate high likelyhood of becoming a default. Hence these 4 looks like strong predictors
# 1. In remaining columns the distributions do not give any obvious insights
# 1. Why loan_amount and income did not give any signs of being strong predictors? May be when we combine these two and get loan to income ratio (LTI), that may have influence on the target variable. We will explore more later

# %% [markdown]
# <h3 style="color:blue" align="center">Feature Engineering, Feature Selection</h3>

# %% [markdown]
# #### Generate Loan to Income (LTI) Ratio

# %%
df_train_1[["loan_amount", "income"]].head(3)
# Out:
#        loan_amount    income
# 12746     23442000  11327000
# 32495      1149000    715000
# 43675     11296000   3195000

# %%
df_train_1['loan_to_income'] = round(df_train_1['loan_amount'] / df_train_1['income'],2)
df_train_1['loan_to_income'].describe()
# Out:
# count   37488.00
# mean        1.56
# std         0.97
# min         0.30
# 25%         0.77
# 50%         1.16
# 75%         2.46
# max         4.57
# Name: loan_to_income, dtype: float64

# %%
df_test['loan_to_income'] = round(df_test['loan_amount'] / df_test['income'],2)

# %%
plt.figure(figsize=(8, 4))
sns.kdeplot(df_train_1['loan_to_income'][df_train_1['default'] == 0], fill=True, label='default=0')
sns.kdeplot(df_train_1['loan_to_income'][df_train_1['default'] == 1], fill=True, label='default=1')
plt.title(f"Loan to Income Ratio (LTI) KDE Plot with Hue by default")
plt.legend()
plt.show()

# %% [markdown]
# **Insights**
# 1. Blue graph has majority of its values on lower side of LTI
# 2. Orange graph has many values when LTI is higher indicating that higher LTI means high risk loan

# %% [markdown]
# #### Generate Delinquency Ratio

# %%
df_train_1['delinquency_ratio'] = (df_train_1['delinquent_months']*100 / df_train_1['total_loan_months']).round(1)
df_test['delinquency_ratio'] = (df_test['delinquent_months']*100 / df_test['total_loan_months']).round(1)

# %%
plt.figure(figsize=(8, 4))
sns.kdeplot(df_train_1['delinquency_ratio'][df_train_1['default'] == 0], fill=True, label='default=0')
sns.kdeplot(df_train_1['delinquency_ratio'][df_train_1['default'] == 1], fill=True, label='default=1')
plt.title(f"Delinquency Ratio KDE Plot with Hue by default")
plt.legend()
plt.show()

# %% [markdown]
# **Insights**
# 1. Blue graph has majority of its values on lower side of LTI
# 2. Orange graph has many values when delinquency ratio is higher indicating some correlation on default

# %% [markdown]
# #### Generate Avg DPD Per Delinquency

# %%
df_train_1['avg_dpd_per_delinquency'] = np.where(
    df_train_1['delinquent_months'] != 0,
    (df_train_1['total_dpd'] / df_train_1['delinquent_months']).round(1),
    0
)

df_test['avg_dpd_per_delinquency'] = np.where(
    df_test['delinquent_months'] != 0,
    (df_test['total_dpd'] / df_test['delinquent_months']).round(1),
    0
)

# %%
plt.figure(figsize=(8, 4))
sns.kdeplot(df_train_1['avg_dpd_per_delinquency'][df_train_1['default'] == 0], fill=True, label='default=0')
sns.kdeplot(df_train_1['avg_dpd_per_delinquency'][df_train_1['default'] == 1], fill=True, label='default=1')
plt.title(f"Avg DPD Per Delinquency Ratio KDE Plot with Hue by default")
plt.legend()
plt.show()

# %% [markdown]
# **Insights**
#
# 1. Graph clearly shows more occurances of default cases when avg_dpd_per_delinquency is high. This means this column is a strong predictor

# %% [markdown]
# ### Remove columns that are just unique ids and don't have influence on target

# %%
df_train_1.columns
# Out:
# Index(['cust_id', 'age', 'gender', 'marital_status', 'employment_status',
#        'income', 'number_of_dependants', 'residence_type',
#        'years_at_current_address', 'city', 'state', 'zipcode', 'loan_id',
#        'loan_purpose', 'loan_type', 'sanction_amount', 'loan_amount',
#        'processing_fee', 'gst', 'net_disbursement', 'loan_tenure_months',
#        'principal_outstanding', 'bank_balance_at_application',
#        'disbursal_date', 'installment_start_dt', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'total_loan_months', 'delinquent_months',
#        'total_dpd', 'enquiry_count', 'credit_utilization_ratio', 'default',
#        'loan_to_income', 'delinquency_ratio', 'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
df_train_2 = df_train_1.drop(['cust_id', 'loan_id'],axis="columns")
df_test = df_test.drop(['cust_id', 'loan_id'],axis="columns")

# %% [markdown]
# ### Remove columns that business contact person asked us to remove

# %%
df_train_3 = df_train_2.drop(['disbursal_date', 'installment_start_dt', 'loan_amount', 'income', 
                              'total_loan_months', 'delinquent_months', 'total_dpd'], axis="columns")
df_test = df_test.drop(['disbursal_date', 'installment_start_dt', 'loan_amount', 'income', 
                              'total_loan_months', 'delinquent_months', 'total_dpd'], axis="columns")
df_train_3.columns
# Out:
# Index(['age', 'gender', 'marital_status', 'employment_status',
#        'number_of_dependants', 'residence_type', 'years_at_current_address',
#        'city', 'state', 'zipcode', 'loan_purpose', 'loan_type',
#        'sanction_amount', 'processing_fee', 'gst', 'net_disbursement',
#        'loan_tenure_months', 'principal_outstanding',
#        'bank_balance_at_application', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'default', 'loan_to_income',
#        'delinquency_ratio', 'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
df_train_3.select_dtypes(['int64', 'float64']).columns
# Out:
# Index(['age', 'number_of_dependants', 'years_at_current_address', 'zipcode',
#        'sanction_amount', 'processing_fee', 'gst', 'net_disbursement',
#        'loan_tenure_months', 'principal_outstanding',
#        'bank_balance_at_application', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'default', 'loan_to_income',
#        'delinquency_ratio', 'avg_dpd_per_delinquency'],
#       dtype='object')

# %% [markdown]
# ### VIF to measure multicolinearity

# %%
X_train = df_train_3.drop('default', axis='columns')
y_train = df_train_3['default']

from sklearn.preprocessing import MinMaxScaler

cols_to_scale = X_train.select_dtypes(['int64', 'float64']).columns

scaler = MinMaxScaler()

X_train[cols_to_scale] = scaler.fit_transform(X_train[cols_to_scale])
X_train.describe()
# Out:
#            age  number_of_dependants  years_at_current_address  zipcode  \
# count 37488.00              37488.00                  37488.00 37488.00
# mean      0.41                  0.39                      0.50     0.52
# std       0.19                  0.31                      0.30     0.29
# min       0.00                  0.00                      0.00     0.00
# 25%       0.29                  0.00                      0.23     0.33
# 50%       0.40                  0.40                      0.50     0.49
# 75%       0.54                  0.60                      0.77     0.76
# max       1.00                  1.00                      1.00     1.00
#
#        sanction_amount  processing_fee      gst  net_disbursement  \
# count         37488.00        37488.00 37488.00          37488.00
# mean              0.09            0.08     0.08              0.08
# std               0.12            0.11     0.11              0.11
# min               0.00            0.00     0.00              0.00
# 25%               0.02            0.02     0.02              0.02
# 50%               0.05            0.05     0.05              0.05
# 75%               0.10            0.10     0.10              0.10
# max               1.00            1.00     1.00              1.00
#
#        loan_tenure_months  principal_outstanding  bank_balance_at_application  \
# count            37488.00               37488.00                     37488.00
# mean                 0.38                   0.26                         0.12
# std                  0.23                   0.24                         0.13
# min                  0.00                   0.00                         0.00
# 25%                  0.19                   0.08                         0.03
# 50%                  0.34                   0.19                         0.08
# 75%                  0.55                   0.35                         0.16
# max                  1.00                   1.00                         1.00
#
#        number_of_open_accounts  number_of_closed_accounts  enquiry_count  \
# count                 37488.00                   37488.00       37488.00
# mean                      0.50                       0.50           0.50
# std                       0.37                       0.41           0.25
# min                       0.00                       0.00           0.00
# 25%                       0.00                       0.00           0.38
# 50%                       0.67                       0.50           0.50
# 75%                       1.00                       1.00           0.62
# max                       1.00                       1.00           1.00
#
#        credit_utilization_ratio  loan_to_income  delinquency_ratio  \
# count                  37488.00        37488.00           37488.00
# mean                       0.44            0.29               0.10
# std                        0.30            0.23               0.17
# min                        0.00            0.00               0.00
# 25%                        0.18            0.11               0.00
# 50%                        0.39            0.20               0.04
# 75%                        0.68            0.51               0.13
# max                        1.00            1.00               1.00
#
#        avg_dpd_per_delinquency
# count                 37488.00
# mean                      0.33
# std                       0.29
# min                       0.00
# 25%                       0.00
# 50%                       0.43
# 75%                       0.57
# max                       1.00

# %% [markdown]
# #### Same transformation on test set

# %%
X_test = df_test.drop('default', axis='columns')
y_test = df_test['default']

X_test[cols_to_scale] = scaler.transform(X_test[cols_to_scale])
X_test.describe()
# Out:
#            age  number_of_dependants  years_at_current_address  zipcode  \
# count 12497.00              12497.00                  12497.00 12497.00
# mean      0.42                  0.38                      0.50     0.53
# std       0.19                  0.31                      0.30     0.29
# min       0.00                  0.00                      0.00     0.00
# 25%       0.29                  0.00                      0.23     0.33
# 50%       0.42                  0.40                      0.50     0.51
# 75%       0.54                  0.60                      0.77     0.76
# max       1.00                  1.00                      1.00     1.00
#
#        sanction_amount  processing_fee      gst  net_disbursement  \
# count         12497.00        12497.00 12497.00          12497.00
# mean              0.09            0.08     0.08              0.08
# std               0.12            0.11     0.11              0.11
# min              -0.00           -0.00    -0.00             -0.00
# 25%               0.02            0.02     0.02              0.02
# 50%               0.05            0.05     0.05              0.05
# 75%               0.10            0.09     0.09              0.09
# max               0.98            0.96     0.96              0.96
#
#        loan_tenure_months  principal_outstanding  bank_balance_at_application  \
# count            12497.00               12497.00                     12497.00
# mean                 0.38                   0.26                         0.12
# std                  0.23                   0.25                         0.13
# min                  0.00                   0.00                         0.00
# 25%                  0.19                   0.08                         0.03
# 50%                  0.34                   0.20                         0.08
# 75%                  0.55                   0.36                         0.16
# max                  1.00                   1.00                         0.94
#
#        number_of_open_accounts  number_of_closed_accounts  enquiry_count  \
# count                 12497.00                   12497.00       12497.00
# mean                      0.50                       0.50           0.50
# std                       0.37                       0.41           0.25
# min                       0.00                       0.00           0.00
# 25%                       0.00                       0.00           0.38
# 50%                       0.33                       0.50           0.50
# 75%                       0.67                       1.00           0.62
# max                       1.00                       1.00           1.00
#
#        credit_utilization_ratio  loan_to_income  delinquency_ratio  \
# count                  12497.00        12497.00           12497.00
# mean                       0.44            0.29               0.11
# std                        0.30            0.23               0.17
# min                        0.00            0.00               0.00
# 25%                        0.18            0.11               0.00
# 50%                        0.39            0.20               0.04
# 75%                        0.68            0.50               0.13
# max                        1.00            1.00               1.00
#
#        avg_dpd_per_delinquency
# count                 12497.00
# mean                      0.33
# std                       0.29
# min                       0.00
# 25%                       0.00
# 50%                       0.44
# 75%                       0.58
# max                       1.00

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calculate_vif(data):
    vif_df = pd.DataFrame()
    vif_df['Column'] = data.columns
    vif_df['VIF'] = [variance_inflation_factor(data.values,i) for i in range(data.shape[1])]
    return vif_df

# %%
X_train.head(2)
# Out:
#        age gender marital_status employment_status  number_of_dependants  \
# 12746 0.79      M        Married     Self-Employed                  0.60
# 32495 0.50      F         Single          Salaried                  0.00
#
#       residence_type  years_at_current_address       city        state  \
# 12746          Owned                      0.97  Hyderabad    Telangana
# 32495          Owned                      0.87     Mumbai  Maharashtra
#
#        zipcode  ... loan_tenure_months principal_outstanding  \
# 12746     0.66  ...               0.42                  1.00
# 32495     0.49  ...               0.83                  0.09
#
#        bank_balance_at_application  number_of_open_accounts  \
# 12746                         0.61                     1.00
# 32495                         0.03                     0.67
#
#        number_of_closed_accounts  enquiry_count  credit_utilization_ratio  \
# 12746                       1.00           0.38                      0.36
# 32495                       0.50           0.50                      0.05
#
#        loan_to_income  delinquency_ratio  avg_dpd_per_delinquency
# 12746            0.41               0.13                     0.59
# 32495            0.31               0.06                     0.62
#
# [2 rows x 26 columns]

# %%
calculate_vif(X_train[cols_to_scale])
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
#                          Column    VIF
# 0                           age   5.70
# 1          number_of_dependants   2.73
# 2      years_at_current_address   3.42
# 3                       zipcode   3.80
# 4               sanction_amount 101.09
# 5                processing_fee    inf
# 6                           gst    inf
# 7              net_disbursement    inf
# 8            loan_tenure_months   6.18
# 9         principal_outstanding  16.33
# 10  bank_balance_at_application   9.34
# 11      number_of_open_accounts   4.39
# 12    number_of_closed_accounts   2.38
# 13                enquiry_count   6.41
# 14     credit_utilization_ratio   2.93
# 15               loan_to_income   6.96
# 16            delinquency_ratio   1.93
# 17      avg_dpd_per_delinquency   2.91

# %%
features_to_drop_vif = ['sanction_amount', 'processing_fee', 'gst', 'net_disbursement','principal_outstanding']


X_train_1 = X_train.drop(features_to_drop_vif, axis='columns')
numeric_columns = X_train_1.select_dtypes(['int64', 'float64']).columns
numeric_columns
# Out:
# Index(['age', 'number_of_dependants', 'years_at_current_address', 'zipcode',
#        'loan_tenure_months', 'bank_balance_at_application',
#        'number_of_open_accounts', 'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
vif_df = calculate_vif(X_train_1[numeric_columns])
vif_df
# Out:
#                          Column  VIF
# 0                           age 5.43
# 1          number_of_dependants 2.73
# 2      years_at_current_address 3.40
# 3                       zipcode 3.78
# 4            loan_tenure_months 6.02
# 5   bank_balance_at_application 1.80
# 6       number_of_open_accounts 4.35
# 7     number_of_closed_accounts 2.37
# 8                 enquiry_count 6.38
# 9      credit_utilization_ratio 2.92
# 10               loan_to_income 4.56
# 11            delinquency_ratio 1.93
# 12      avg_dpd_per_delinquency 2.91

# %%
selected_numeric_features_vif = vif_df.Column.values
selected_numeric_features_vif
# Out:
# array(['age', 'number_of_dependants', 'years_at_current_address',
#        'zipcode', 'loan_tenure_months', 'bank_balance_at_application',
#        'number_of_open_accounts', 'number_of_closed_accounts',
#        'enquiry_count', 'credit_utilization_ratio', 'loan_to_income',
#        'delinquency_ratio', 'avg_dpd_per_delinquency'], dtype=object)

# %%
numeric_columns
# Out:
# Index(['age', 'number_of_dependants', 'years_at_current_address', 'zipcode',
#        'loan_tenure_months', 'bank_balance_at_application',
#        'number_of_open_accounts', 'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
numeric_columns
# Out:
# Index(['age', 'number_of_dependants', 'years_at_current_address', 'zipcode',
#        'loan_tenure_months', 'bank_balance_at_application',
#        'number_of_open_accounts', 'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
plt.figure(figsize=(12,12))
cm = df_train_3[numeric_columns.append(pd.Index(['default']))].corr()
sns.heatmap(cm, annot=True, fmt='0.2f')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Feature Selection: Categorical Features

# %%
X_train_1.head()
# Out:
#        age gender marital_status employment_status  number_of_dependants  \
# 12746 0.79      M        Married     Self-Employed                  0.60
# 32495 0.50      F         Single          Salaried                  0.00
# 43675 0.38      M         Single          Salaried                  0.00
# 9040  0.46      M        Married          Salaried                  0.40
# 13077 0.77      M        Married     Self-Employed                  0.80
#
#       residence_type  years_at_current_address       city        state  \
# 12746          Owned                      0.97  Hyderabad    Telangana
# 32495          Owned                      0.87     Mumbai  Maharashtra
# 43675       Mortgage                      0.83    Chennai   Tamil Nadu
# 9040        Mortgage                      0.97  Bangalore    Karnataka
# 13077          Owned                      0.93       Pune  Maharashtra
#
#        zipcode  ...  loan_type loan_tenure_months  \
# 12746     0.66  ...    Secured               0.42
# 32495     0.49  ...    Secured               0.83
# 43675     0.83  ...    Secured               0.49
# 9040      0.76  ...    Secured               0.64
# 13077     0.51  ...  Unsecured               0.17
#
#        bank_balance_at_application  number_of_open_accounts  \
# 12746                         0.61                     1.00
# 32495                         0.03                     0.67
# 43675                         0.17                     0.00
# 9040                          0.08                     0.67
# 13077                         0.07                     0.00
#
#        number_of_closed_accounts  enquiry_count  credit_utilization_ratio  \
# 12746                       1.00           0.38                      0.36
# 32495                       0.50           0.50                      0.05
# 43675                       0.50           0.38                      0.00
# 9040                        0.00           0.88                      0.88
# 13077                       1.00           0.00                      0.72
#
#        loan_to_income  delinquency_ratio  avg_dpd_per_delinquency
# 12746            0.41               0.13                     0.59
# 32495            0.31               0.06                     0.62
# 43675            0.76               0.22                     0.56
# 9040             0.19               0.00                     0.00
# 13077            0.05               0.00                     0.00
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Calculate WOE and IV

# %%
def calculate_woe_iv(df, feature, target):
    grouped = df.groupby(feature)[target].agg(['count','sum'])
    grouped = grouped.rename(columns={'count': 'total', 'sum': 'good'})
    grouped['bad']=grouped['total']-grouped['good']
    
    total_good = grouped['good'].sum()
    total_bad = grouped['bad'].sum()
    
    grouped['good_pct'] = grouped['good'] / total_good
    grouped['bad_pct'] = grouped['bad'] / total_bad
    grouped['woe'] = np.log(grouped['good_pct']/ grouped['bad_pct'])
    grouped['iv'] = (grouped['good_pct'] -grouped['bad_pct'])*grouped['woe']
    
    grouped['woe'] = grouped['woe'].replace([np.inf, -np.inf], 0)
    grouped['iv'] = grouped['iv'].replace([np.inf, -np.inf], 0)
    
    total_iv = grouped['iv'].sum()
    
    return grouped, total_iv

grouped, total_iv = calculate_woe_iv(pd.concat([X_train_1, y_train],axis=1), 'loan_purpose', 'default')
grouped
# Out:
#               total  good    bad  good_pct  bad_pct   woe   iv
# loan_purpose
# Auto           7447   327   7120      0.10     0.21 -0.72 0.08
# Education      5620   559   5061      0.17     0.15  0.16 0.00
# Home          11304  1734   9570      0.54     0.28  0.66 0.17
# Personal      13117   603  12514      0.19     0.37 -0.67 0.12

# %%
X_train_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37488 entries, 12746 to 37784
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   age                          37488 non-null  float64
#  1   gender                       37488 non-null  object
#  2   marital_status               37488 non-null  object
#  3   employment_status            37488 non-null  object
#  4   number_of_dependants         37488 non-null  float64
#  5   residence_type               37488 non-null  object
#  6   years_at_current_address     37488 non-null  float64
#  7   city                         37488 non-null  object
#  8   state                        37488 non-null  object
#  9   zipcode                      37488 non-null  float64
#  10  loan_purpose                 37488 non-null  object
#  11  loan_type                    37488 non-null  object
#  12  loan_tenure_months           37488 non-null  float64
#  13  bank_balance_at_application  37488 non-null  float64
#  14  number_of_open_accounts      37488 non-null  float64
#  15  number_of_closed_accounts    37488 non-null  float64
#  16  enquiry_count                37488 non-null  float64
#  17  credit_utilization_ratio     37488 non-null  float64
#  18  loan_to_income               37488 non-null  float64
#  19  delinquency_ratio            37488 non-null  float64
#  20  avg_dpd_per_delinquency      37488 non-null  float64
# dtypes: float64(13), object(8)
# memory usage: 6.3+ MB

# %%
iv_values = {}

for feature in X_train_1.columns:
    if X_train_1[feature].dtype == 'object':
        _, iv = calculate_woe_iv(pd.concat([X_train_1, y_train],axis=1), feature, 'default' )
    else:
        X_binned = pd.cut(X_train_1[feature], bins=10, labels=False)
        _, iv = calculate_woe_iv(pd.concat([X_binned, y_train],axis=1), feature, 'default' )
    iv_values[feature] = iv
        
iv_values
# Out:
# {'age': 0.0890689462679479,
#  'gender': 0.00047449502170914947,
#  'marital_status': 0.001129766845390142,
#  'employment_status': 0.003953046301722585,
#  'number_of_dependants': 0.0019380899135053508,
#  'residence_type': 0.246745268718145,
#  'years_at_current_address': 0.0020800513608156363,
#  'city': 0.0019059578709781529,
#  'state': 0.0019005589806779287,
#  'zipcode': 0.0016677413243392572,
#  'loan_purpose': 0.3691197842282755,
#  'loan_type': 0.16319324904149224,
#  'loan_tenure_months': 0.21893515090196278,
#  'bank_balance_at_application': 0.0063187993277516365,
#  'number_of_open_accounts': 0.08463134083005877,
#  'number_of_closed_accounts': 0.0011964272592421567,
#  'enquiry_count': 0.007864214085342608,
#  'credit_utilization_ratio': 2.352965568168245,
#  'loan_to_income': 0.476415456948364,
#  'delinquency_ratio': 0.716576108689321,
#  'avg_dpd_per_delinquency': 0.40151905412190175}

# %%
pd.set_option('display.float_format', lambda x: '{:.3f}'.format(x))

iv_df = pd.DataFrame(list(iv_values.items()), columns=['Feature', 'IV'])
iv_df = iv_df.sort_values(by='IV', ascending=False)
iv_df
# Out:
#                         Feature    IV
# 17     credit_utilization_ratio 2.353
# 19            delinquency_ratio 0.717
# 18               loan_to_income 0.476
# 20      avg_dpd_per_delinquency 0.402
# 10                 loan_purpose 0.369
# 5                residence_type 0.247
# 12           loan_tenure_months 0.219
# 11                    loan_type 0.163
# 0                           age 0.089
# 14      number_of_open_accounts 0.085
# 16                enquiry_count 0.008
# 13  bank_balance_at_application 0.006
# 3             employment_status 0.004
# 6      years_at_current_address 0.002
# 4          number_of_dependants 0.002
# 7                          city 0.002
# 8                         state 0.002
# 9                       zipcode 0.002
# 15    number_of_closed_accounts 0.001
# 2                marital_status 0.001
# 1                        gender 0.000

# %%
# select features that has IV > 0.02
selected_features_iv = [feature for feature, iv in iv_values.items() if iv > 0.02]
selected_features_iv
# Out:
# ['age',
#  'residence_type',
#  'loan_purpose',
#  'loan_type',
#  'loan_tenure_months',
#  'number_of_open_accounts',
#  'credit_utilization_ratio',
#  'loan_to_income',
#  'delinquency_ratio',
#  'avg_dpd_per_delinquency']

# %% [markdown]
# ### Feature Encoding

# %%
X_train_reduced = X_train_1[selected_features_iv]
X_test_reduced = X_test[selected_features_iv]

# %%
X_train_encoded = pd.get_dummies(X_train_reduced, drop_first=True)
X_train_encoded.head(3)
# Out:
#         age  loan_tenure_months  number_of_open_accounts  \
# 12746 0.788               0.415                    1.000
# 32495 0.500               0.830                    0.667
# 43675 0.385               0.491                    0.000
#
#        credit_utilization_ratio  loan_to_income  delinquency_ratio  \
# 12746                     0.364           0.415              0.132
# 32495                     0.051           0.307              0.062
# 43675                     0.000           0.759              0.222
#
#        avg_dpd_per_delinquency  residence_type_Owned  residence_type_Rented  \
# 12746                    0.590                  True                  False
# 32495                    0.620                  True                  False
# 43675                    0.560                 False                  False
#
#        loan_purpose_Education  loan_purpose_Home  loan_purpose_Personal  \
# 12746                   False               True                  False
# 32495                    True              False                  False
# 43675                   False               True                  False
#
#        loan_type_Unsecured
# 12746                False
# 32495                False
# 43675                False

# %%
X_test_encoded = pd.get_dummies(X_test_reduced, drop_first=True)
X_test_encoded.head(3)
# Out:
#         age  loan_tenure_months  number_of_open_accounts  \
# 19205 0.346               0.755                    0.333
# 15514 0.481               0.226                    1.000
# 30367 0.231               0.547                    0.667
#
#        credit_utilization_ratio  loan_to_income  delinquency_ratio  \
# 19205                     0.990           0.550              0.000
# 15514                     0.323           0.220              0.000
# 30367                     0.828           0.180              0.000
#
#        avg_dpd_per_delinquency  residence_type_Owned  residence_type_Rented  \
# 19205                    0.000                  True                  False
# 15514                    0.000                  True                  False
# 30367                    0.000                  True                  False
#
#        loan_purpose_Education  loan_purpose_Home  loan_purpose_Personal  \
# 19205                   False               True                  False
# 15514                    True              False                  False
# 30367                   False              False                  False
#
#        loan_type_Unsecured
# 19205                False
# 15514                False
# 30367                False

# %% [markdown]
# <h3 align="center" style="color:blue">Model Training</h3>

# %% [markdown]
# ### Attempt 1
#
# 1. Logistic Regression, RandomForest & XGB
# 1. No handling of class imbalance

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

model = LogisticRegression()
model.fit(X_train_encoded, y_train)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     11423
#            1       0.85      0.72      0.78      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.91      0.85      0.88     12497
# weighted avg       0.96      0.96      0.96     12497

# %%
feature_importance = model.coef_[0]

# Create a DataFrame for easier handling
coef_df = pd.DataFrame(feature_importance, index=X_train_encoded.columns, columns=['Coefficients'])

# Sort the coefficients for better visualization
coef_df = coef_df.sort_values(by='Coefficients', ascending=True)

# Plotting
plt.figure(figsize=(8, 4))
plt.barh(coef_df.index, coef_df['Coefficients'], color='steelblue')
plt.xlabel('Coefficient Value')
plt.title('Feature Importance in Logistic Regression')
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
model.fit(X_train_encoded, y_train)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     11423
#            1       0.86      0.71      0.78      1074
#
#     accuracy                           0.97     12497
#    macro avg       0.92      0.85      0.88     12497
# weighted avg       0.96      0.97      0.96     12497

# %%
from xgboost import XGBClassifier

model = XGBClassifier()
model.fit(X_train_encoded, y_train)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98     11423
#            1       0.82      0.76      0.79      1074
#
#     accuracy                           0.97     12497
#    macro avg       0.90      0.87      0.89     12497
# weighted avg       0.96      0.97      0.96     12497

# %% [markdown]
# Since there is not much difference between XGB and Logistic, we will choose LogisticRegression as a candidate for our RandomizedSearchCV candidate it has a better interpretation.

# %% [markdown]
# #### RandomizedSearch CV for Attempt 1: Logistic Regression

# %%
from sklearn.model_selection import RandomizedSearchCV

param_dist = {
    'C': np.logspace(-4, 4, 20),  # Logarithmically spaced values from 10^-4 to 10^4
    'solver': ['lbfgs', 'saga', 'liblinear', 'newton-cg']   # Algorithm to use in the optimization problem
}

# Create the Logistic Regression model
log_reg = LogisticRegression(max_iter=10000)  # Increased max_iter for convergence

# Set up RandomizedSearchCV
random_search = RandomizedSearchCV(
    estimator=log_reg,
    param_distributions=param_dist,
    n_iter=50,  # Number of parameter settings that are sampled
    scoring='f1',
    cv=3,  # 5-fold cross-validation
    verbose=2,
    random_state=42,  # Set a random state for reproducibility
    n_jobs=-1  # Use all available cores
)

# Fit the RandomizedSearchCV to the training data
random_search.fit(X_train_encoded, y_train)

# Print the best parameters and best score
print(f"Best Parameters: {random_search.best_params_}")
print(f"Best Score: {random_search.best_score_}")

best_model = random_search.best_estimator_
y_pred = best_model.predict(X_test_encoded)
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# [CV] END ............C=0.08858667904100823, solver=liblinear; total time=   0.0s
# [CV] END ............C=0.08858667904100823, solver=liblinear; total time=   0.0s
# [CV] END ...........C=0.004832930238571752, solver=liblinear; total time=   0.0s
# [CV] END ............C=0.08858667904100823, solver=liblinear; total time=   0.0s
# [CV] END ................C=0.08858667904100823, solver=lbfgs; total time=   0.0s
# [CV] END ................C=0.08858667904100823, solver=lbfgs; total time=   0.0s
# [CV] END .............................C=0.0001, solver=lbfgs; total time=   0.0s
# [CV] END ................C=0.08858667904100823, solver=lbfgs; total time=   0.0s
# [CV] END ..........C=0.0006951927961775605, solver=liblinear; total time=   0.0s
# [CV] END ..........C=0.0006951927961775605, solver=liblinear; total time=   0.0s
# [CV] END ..........C=0.0006951927961775605, solver=liblinear; total time=   0.0s
# [CV] END .............................C=0.0001, solver=lbfgs; total time=   0.0s
# [CV] END .............................C=0.0001, solver=lbfgs; total time=   0.0s
# [CV] END .............C=0.00026366508987303583, solver=lbfgs; total time=   0.0s
# [CV] END ...............C=1438.44988828766, solver=liblinear; total time=   0.0s
# [CV] END ...............C=1438.44988828766, solver=liblinear; total time=   0.1s
# [CV] END .............C=0.00026366508987303583, solver=lbfgs; total time=   0.0s
# [CV] END ...............C=1438.44988828766, solver=liblinear; total time=   0.1s
# [CV] END .............C=0.00026366508987303583, solver=lbfgs; total time=   0.0s
# [CV] END ..............C=0.0018329807108324356, solver=lbfgs; total time=   0.0s
# [CV] END ..............C=0.0018329807108324356, solver=lbfgs; total time=   0.0s
# [CV] END ..............C=0.0018329807108324356, solver=lbfgs; total time=   0.0s
# [CV] END ...........C=0.012742749857031334, solver=liblinear; total time=   0.0s
# [CV] END ............C=0.08858667904100823, solver=newton-cg; total time=   0.0s
# [CV] END ...........C=0.012742749857031334, solver=liblinear; total time=   0.0s
# [CV] END ...........C=0.012742749857031334, solver=liblinear; total time=   0.0s
# [CV] END ............C=0.08858667904100823, solver=newton-cg; total time=   0.0s
# [CV] END ..................C=11.288378916846883, solver=saga; total time=   0.1s
# [CV] END .................C=0.23357214690901212, solver=saga; total time=   0.0s
# [CV] END .................C=0.23357214690901212, solver=saga; total time=   0.1s
# [CV] END ..............C=545.5594781168514, solver=newton-cg; total time=   0.0s
# [CV] END ..................C=11.288378916846883, solver=saga; total time=   0.1s
# [CV] END ..................C=11.288378916846883, solver=saga; total time=   0.1s
# [CV] END ............C=0.08858667904100823, solver=newton-cg; total time=   0.0s
# [CV] END ..............C=545.5594781168514, solver=newton-cg; total time=   0.1s
# [CV] END .................C=0.23357214690901212, solver=saga; total time=   0.1s
# [CV] END ...................C=1438.44988828766, solver=lbfgs; total time=   0.0s
# [CV] END ............C=0.23357214690901212, solver=newton-cg; total time=   0.0s
# [CV] END ...................C=1438.44988828766, solver=lbfgs; total time=   0.0s
# [CV] END ..............C=545.5594781168514, solver=newton-cg; total time=   0.1s
# [CV] END ...................C=1438.44988828766, solver=lbfgs; total time=   0.0s
# [CV] END ............C=0.23357214690901212, solver=newton-cg; total time=   0.0s
# [CV] END ............C=0.23357214690901212, solver=newton-cg; total time=   0.0s
# [CV] END ...........C=0.004832930238571752, solver=liblinear; total time=   0.0s
# [CV] END ...........C=0.004832930238571752, solver=liblinear; total time=   0.0s
# [CV] END ...................C=4.281332398719396, solver=saga; total time=   0.1s
# [CV] END ...................C=4.281332398719396, solver=saga; total time=   0.1s
# [CV] END ...................C=4.281332398719396, solver=saga; total time=   0.1s
# [CV] END .............C=29.763514416313132, solver=newton-cg; total time=   0.0s
# [CV] END .............C=29.763514416313132, solver=newton-cg; total time=   0.1s
# [CV] END ....................C=206.913808111479, solver=saga; total time=   0.1s
# [CV] END ...................C=3792.690190732246, solver=saga; total time=   0.1s
# [CV] END ..................C=1.623776739188721, solver=lbfgs; total time=   0.0s
# [CV] END ...................C=3792.690190732246, solver=saga; total time=   0.1s
# [CV] END ....................C=206.913808111479, solver=saga; total time=   0.1s
# [CV] END .............C=29.763514416313132, solver=newton-cg; total time=   0.1s
# [CV] END ...................C=3792.690190732246, solver=saga; total time=   0.1s
# [CV] END ....................C=206.913808111479, solver=saga; total time=   0.1s
# [CV] END ..................C=1.623776739188721, solver=lbfgs; total time=   0.0s
# [CV] END ..................C=1.623776739188721, solver=lbfgs; total time=   0.0s
# [CV] END ..................C=545.5594781168514, solver=lbfgs; total time=   0.0s
# [CV] END ..................C=545.5594781168514, solver=lbfgs; total time=   0.0s
# [CV] END ..................C=545.5594781168514, solver=lbfgs; total time=   0.0s
# [CV] END ...............C=0.0006951927961775605, solver=saga; total time=   0.1s
# [CV] END ...............C=0.0006951927961775605, solver=saga; total time=   0.1s
# [CV] END ...............C=0.0006951927961775605, solver=saga; total time=   0.1s
# [CV] END ..............C=4.281332398719396, solver=newton-cg; total time=   0.0s
# [CV] END ..............C=0.00026366508987303583, solver=saga; total time=   0.1s
# [CV] END ..............C=4.281332398719396, solver=newton-cg; total time=   0.0s
# [CV] END ..............C=0.00026366508987303583, solver=saga; total time=   0.1s
# [CV] END ..............C=0.00026366508987303583, solver=saga; total time=   0.1s
# [CV] END ..............C=4.281332398719396, solver=newton-cg; total time=   0.1s
# [CV] END ............C=0.23357214690901212, solver=liblinear; total time=   0.0s
# [CV] END ............C=0.23357214690901212, solver=liblinear; total time=   0.0s
# [CV] END ............C=0.23357214690901212, solver=liblinear; total time=   0.0s
# [CV] END ...............C=206.913808111479, solver=liblinear; total time=   0.0s
# [CV] END ...............C=0.004832930238571752, solver=lbfgs; total time=   0.0s
# [CV] END ...............C=206.913808111479, solver=liblinear; total time=   0.1s
# [CV] END ...............C=0.004832930238571752, solver=lbfgs; total time=   0.0s
# [CV] END ...............C=0.004832930238571752, solver=lbfgs; total time=   0.0s
# [CV] END ...............C=206.913808111479, solver=liblinear; total time=   0.1s
# [CV] END ..............C=1.623776739188721, solver=liblinear; total time=   0.0s
# [CV] END ..............C=1.623776739188721, solver=liblinear; total time=   0.1s
# [CV] END ..............C=1.623776739188721, solver=liblinear; total time=   0.1s
# [CV] END .............C=29.763514416313132, solver=liblinear; total time=   0.0s
# [CV] END .............C=29.763514416313132, solver=liblinear; total time=   0.0s
# [CV] END .............C=29.763514416313132, solver=liblinear; total time=   0.0s
# [CV] END ..............C=0.615848211066026, solver=newton-cg; total time=   0.0s
# [CV] END ..................C=78.47599703514607, solver=lbfgs; total time=   0.0s
# [CV] END ..................C=78.47599703514607, solver=lbfgs; total time=   0.0s
# [CV] END ..............C=0.615848211066026, solver=newton-cg; total time=   0.0s
# [CV] END ..............C=0.615848211066026, solver=newton-cg; total time=   0.0s
# [CV] END ..................C=78.47599703514607, solver=lbfgs; total time=   0.0s
# [CV] END .........C=0.00026366508987303583, solver=newton-cg; total time=   0.0s
# [CV] END .........C=0.00026366508987303583, solver=newton-cg; total time=   0.0s
# [CV] END .........C=0.00026366508987303583, solver=newton-cg; total time=   0.0s
# [CV] END ........................C=10000.0, solver=newton-cg; total time=   0.0s
# [CV] END ........................C=10000.0, solver=newton-cg; total time=   0.0s
# [CV] END ........................C=10000.0, solver=newton-cg; total time=   0.0s
# [CV] END ...........C=0.004832930238571752, solver=newton-cg; total time=   0.0s
# [CV] END .............C=11.288378916846883, solver=liblinear; total time=   0.1s
# [CV] END ..................C=4.281332398719396, solver=lbfgs; total time=   0.0s
# [CV] END .............C=11.288378916846883, solver=liblinear; total time=   0.0s
# [CV] END ..................C=29.763514416313132, solver=saga; total time=   0.1s
# [CV] END ..............C=545.5594781168514, solver=liblinear; total time=   0.0s
# [CV] END ..................C=4.281332398719396, solver=lbfgs; total time=   0.0s
# [CV] END ...........C=0.004832930238571752, solver=newton-cg; total time=   0.0s
# [CV] END ..............C=545.5594781168514, solver=liblinear; total time=   0.1s
# [CV] END ............................C=10000.0, solver=lbfgs; total time=   0.0s
# [CV] END ............................C=10000.0, solver=lbfgs; total time=   0.0s
# [CV] END ..................C=29.763514416313132, solver=saga; total time=   0.1s
# [CV] END ...............C=0.0018329807108324356, solver=saga; total time=   0.0s
# [CV] END .................C=0.03359818286283781, solver=saga; total time=   0.1s
# [CV] END ..................C=4.281332398719396, solver=lbfgs; total time=   0.0s
# [CV] END .........................C=0.0001, solver=newton-cg; total time=   0.0s
# [CV] END .........................C=0.0001, solver=newton-cg; total time=   0.0s
# [CV] END .............C=11.288378916846883, solver=liblinear; total time=   0.0s
# [CV] END ..............C=545.5594781168514, solver=liblinear; total time=   0.0s
# [CV] END ...............C=0.0018329807108324356, solver=saga; total time=   0.0s
# [CV] END .........................C=0.0001, solver=newton-cg; total time=   0.0s
# [CV] END ...........C=0.004832930238571752, solver=newton-cg; total time=   0.0s
# [CV] END ............................C=10000.0, solver=lbfgs; total time=   0.0s
# [CV] END ................C=0.004832930238571752, solver=saga; total time=   0.1s
# [CV] END ..................C=29.763514416313132, solver=saga; total time=   0.1s
# [CV] END ................C=0.004832930238571752, solver=saga; total time=   0.1s
# [CV] END ...............C=0.0018329807108324356, solver=saga; total time=   0.1s
# [CV] END .................C=0.03359818286283781, solver=saga; total time=   0.1s
# [CV] END ..............C=0.0006951927961775605, solver=lbfgs; total time=   0.0s
# [CV] END ..............C=0.0006951927961775605, solver=lbfgs; total time=   0.0s
# [CV] END .................C=0.03359818286283781, solver=saga; total time=   0.1s
# [CV] END ..............C=0.0006951927961775605, solver=lbfgs; total time=   0.0s
# [CV] END ................C=0.004832930238571752, solver=saga; total time=   0.1s
# [CV] END ..............C=0.615848211066026, solver=liblinear; total time=   0.0s
# [CV] END ..............C=0.615848211066026, solver=liblinear; total time=   0.0s
# [CV] END ..............C=0.615848211066026, solver=liblinear; total time=   0.0s
# [CV] END .........C=0.00026366508987303583, solver=liblinear; total time=   0.0s
# [CV] END .........C=0.00026366508987303583, solver=liblinear; total time=   0.0s
# [CV] END .........C=0.00026366508987303583, solver=liblinear; total time=   0.0s
# [CV] END ..................C=0.615848211066026, solver=lbfgs; total time=   0.0s
# [CV] END ..................C=3792.690190732246, solver=lbfgs; total time=   0.0s
# [CV] END ..................C=0.615848211066026, solver=lbfgs; total time=   0.0s
# [CV] END ..................C=0.615848211066026, solver=lbfgs; total time=   0.0s
# [CV] END ..................C=3792.690190732246, solver=lbfgs; total time=   0.0s
# [CV] END ..................C=3792.690190732246, solver=lbfgs; total time=   0.0s
# [CV] END ...................C=545.5594781168514, solver=saga; total time=   0.1s
# [CV] END ...................C=545.5594781168514, solver=saga; total time=   0.1s
# [CV] END ...................C=545.5594781168514, solver=saga; total time=   0.1s
# [CV] END ..............C=78.47599703514607, solver=liblinear; total time=   0.0s
# [CV] END ..............C=78.47599703514607, solver=liblinear; total time=   0.0s
# [CV] END ..............C=78.47599703514607, solver=liblinear; total time=   0.0s
# Best Parameters: {'solver': 'saga', 'C': 3792.690190732246}
# Best Score: 0.7578820896729832
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98     11423
#            1       0.83      0.74      0.78      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.90      0.86      0.88     12497
# weighted avg       0.96      0.96      0.96     12497

# %% [markdown]
# #### RandomizedSearch CV for Attempt 1: XGBoost

# %%
from scipy.stats import uniform, randint
from sklearn.model_selection import RandomizedSearchCV

# Define parameter distribution for RandomizedSearchCV
param_dist = {
    'n_estimators': [100, 150, 200, 250, 300],
    'max_depth': [3, 4, 5, 6, 7, 8, 9, 10],
    'learning_rate': [0.01, 0.03, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3],
    'subsample': [0.6, 0.7, 0.8, 0.9, 1.0],
    'colsample_bytree': [0.6, 0.7, 0.8, 0.9, 1.0],
    'scale_pos_weight': [1, 2, 3, 5, 7, 10],
    'reg_alpha': [0.01, 0.1, 0.5, 1.0, 5.0, 10.0],  # L1 regularization term
    'reg_lambda': [0.01, 0.1, 0.5, 1.0, 5.0, 10.0]  # L2 regularization term
}

xgb = XGBClassifier()

random_search = RandomizedSearchCV(estimator=xgb, param_distributions=param_dist, n_iter=100,
                                   scoring='f1', cv=3, verbose=1, n_jobs=-1, random_state=42)

random_search.fit(X_train_encoded, y_train)

# Print the best parameters and best score
print(f"Best Parameters: {random_search.best_params_}")
print(f"Best Score: {random_search.best_score_}")

best_model = random_search.best_estimator_
y_pred = best_model.predict(X_test_encoded)
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Best Parameters: {'subsample': 0.7, 'scale_pos_weight': 2, 'reg_lambda': 10.0, 'reg_alpha': 0.01, 'n_estimators': 100, 'max_depth': 4, 'learning_rate': 0.2, 'colsample_bytree': 0.8}
# Best Score: 0.7885351531443989
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98     11423
#            1       0.76      0.84      0.80      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.87      0.91      0.89     12497
# weighted avg       0.97      0.96      0.96     12497

# %% [markdown]
# ### Attempt 2
#
# 1. Logistic Regression & XGB
# 1. Handle Class Imbalance Using Under Sampling

# %%
from imblearn.under_sampling import RandomUnderSampler

rus = RandomUnderSampler(random_state=42)
X_train_res, y_train_res = rus.fit_resample(X_train_encoded, y_train)
y_train_res.value_counts()
# Out:
# default
# 0    3223
# 1    3223
# Name: count, dtype: int64

# %%
model = LogisticRegression()
model.fit(X_train_res, y_train_res)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.91      0.95     11423
#            1       0.51      0.96      0.67      1074
#
#     accuracy                           0.92     12497
#    macro avg       0.75      0.93      0.81     12497
# weighted avg       0.95      0.92      0.93     12497

# %%
model = XGBClassifier(**random_search.best_params_)
model.fit(X_train_res, y_train_res)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.91      0.95     11423
#            1       0.52      0.98      0.68      1074
#
#     accuracy                           0.92     12497
#    macro avg       0.76      0.95      0.82     12497
# weighted avg       0.96      0.92      0.93     12497

# %% [markdown]
# ### Attempt 3
#
# 1. Logistic Regression
# 1. Handle Class Imbalance Using SMOTE Tomek
# 1. Parameter tunning using optuna

# %%
from imblearn.combine import SMOTETomek

smt = SMOTETomek(random_state=42)
X_train_smt, y_train_smt = smt.fit_resample(X_train_encoded, y_train)
y_train_smt.value_counts()
# Out:
# default
# 0    34195
# 1    34195
# Name: count, dtype: int64

# %%
model = LogisticRegression()
model.fit(X_train_smt, y_train_smt)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96     11423
#            1       0.55      0.94      0.70      1074
#
#     accuracy                           0.93     12497
#    macro avg       0.77      0.94      0.83     12497
# weighted avg       0.96      0.93      0.94     12497

# %%
import optuna
from sklearn.metrics import make_scorer, f1_score
from sklearn.model_selection import cross_val_score

# %%
# Define the objective function for Optuna
def objective(trial):
    param = {
        'C': trial.suggest_float('C', 1e-4, 1e4, log=True),  # Logarithmically spaced values
        'solver': trial.suggest_categorical('solver', ['lbfgs', 'liblinear', 'saga', 'newton-cg']),  # Solvers
        'tol': trial.suggest_float('tol', 1e-6, 1e-1, log=True),  # Logarithmically spaced values for tolerance
        'class_weight': trial.suggest_categorical('class_weight', [None, 'balanced'])  # Class weights
    }

    model = LogisticRegression(**param, max_iter=10000)
    
    # Calculate the cross-validated f1_score
    f1_scorer = make_scorer(f1_score, average='macro')
    scores = cross_val_score(model, X_train_smt, y_train_smt, cv=3, scoring=f1_scorer, n_jobs=-1)
    
    return np.mean(scores)

study_logistic = optuna.create_study(direction='maximize')
study_logistic.optimize(objective, n_trials=50)
# Out:
# [I 2025-10-06 19:09:09,199] A new study created in memory with name: no-name-833f0049-c90e-44b9-a725-827fe52a237e
# [I 2025-10-06 19:09:09,271] Trial 0 finished with value: 0.8601857901771565 and parameters: {'C': 0.006951853583946708, 'solver': 'newton-cg', 'tol': 0.07112280462147015, 'class_weight': 'balanced'}. Best is trial 0 with value: 0.8601857901771565.
# [I 2025-10-06 19:09:09,374] Trial 1 finished with value: 0.9414914626742124 and parameters: {'C': 10.687417120435914, 'solver': 'lbfgs', 'tol': 0.001936827261159666, 'class_weight': None}. Best is trial 1 with value: 0.9414914626742124.
# [I 2025-10-06 19:09:09,475] Trial 2 finished with value: 0.9408156616833653 and parameters: {'C': 0.09225905864499202, 'solver': 'saga', 'tol': 0.0028227754107487727, 'class_weight': None}. Best is trial 1 with value: 0.9414914626742124.
# [I 2025-10-06 19:09:09,579] Trial 3 finished with value: 0.9458092207506716 and parameters: {'C': 2.6966251330306887, 'solver': 'saga', 'tol': 1.5167447485256297e-05, 'class_weight': None}. Best is trial 3 with value: 0.9458092207506716.
# [I 2025-10-06 19:09:09,669] Trial 4 finished with value: 0.9456062390565747 and parameters: {'C': 65.30049811945086, 'solver': 'newton-cg', 'tol': 4.504608455060257e-05, 'class_weight': None}. Best is trial 3 with value: 0.9458092207506716.
# [I 2025-10-06 19:09:09,734] Trial 5 finished with value: 0.9272304127372274 and parameters: {'C': 0.008119841100863426, 'solver': 'saga', 'tol': 0.0245473389328343, 'class_weight': 'balanced'}. Best is trial 3 with value: 0.9458092207506716.
# [I 2025-10-06 19:09:09,789] Trial 6 finished with value: 0.8273929425929024 and parameters: {'C': 0.00012133710520391351, 'solver': 'lbfgs', 'tol': 0.009547004449268572, 'class_weight': None}. Best is trial 3 with value: 0.9458092207506716.
# [I 2025-10-06 19:09:09,853] Trial 7 finished with value: 0.9080195651133378 and parameters: {'C': 3720.8587553261214, 'solver': 'newton-cg', 'tol': 0.024643758697375437, 'class_weight': 'balanced'}. Best is trial 3 with value: 0.9458092207506716.
# [I 2025-10-06 19:09:09,979] Trial 8 finished with value: 0.9456354327232822 and parameters: {'C': 47.527967169900535, 'solver': 'saga', 'tol': 2.5184958758797625e-05, 'class_weight': 'balanced'}. Best is trial 3 with value: 0.9458092207506716.
# [I 2025-10-06 19:09:10,054] Trial 9 finished with value: 0.9019640112076468 and parameters: {'C': 0.002824322383556423, 'solver': 'liblinear', 'tol': 4.276257136704282e-05, 'class_weight': 'balanced'}. Best is trial 3 with value: 0.9458092207506716.
# [I 2025-10-06 19:09:10,181] Trial 10 finished with value: 0.9454699661810775 and parameters: {'C': 1.3874122107742632, 'solver': 'liblinear', 'tol': 1.0291936383284472e-06, 'class_weight': None}. Best is trial 3 with value: 0.9458092207506716.
# [I 2025-10-06 19:09:10,311] Trial 11 finished with value: 0.9456648044554358 and parameters: {'C': 302.16149300109237, 'solver': 'saga', 'tol': 3.3105482875942875e-06, 'class_weight': 'balanced'}. Best is trial 3 with value: 0.9458092207506716.
# [I 2025-10-06 19:09:10,469] Trial 12 finished with value: 0.9456794085990863 and parameters: {'C': 3215.834792243382, 'solver': 'saga', 'tol': 1.6329377525180473e-06, 'class_weight': None}. Best is trial 3 with value: 0.9458092207506716.
# [I 2025-10-06 19:09:10,613] Trial 13 finished with value: 0.9456794085990863 and parameters: {'C': 9248.579992861285, 'solver': 'saga', 'tol': 5.809928091464504e-06, 'class_weight': None}. Best is trial 3 with value: 0.9458092207506716.
# [I 2025-10-06 19:09:10,703] Trial 14 finished with value: 0.9457795826636404 and parameters: {'C': 2.3298901376800374, 'solver': 'saga', 'tol': 0.00021377606875704945, 'class_weight': None}. Best is trial 3 with value: 0.9458092207506716.
# [I 2025-10-06 19:09:10,794] Trial 15 finished with value: 0.9455283836542261 and parameters: {'C': 0.8580364334600802, 'solver': 'saga', 'tol': 0.0002865220899991767, 'class_weight': None}. Best is trial 3 with value: 0.9458092207506716.
# [I 2025-10-06 19:09:10,894] Trial 16 finished with value: 0.9452936684429961 and parameters: {'C': 0.633106154789727, 'solver': 'saga', 'tol': 0.0003098588599624767, 'class_weight': None}. Best is trial 3 with value: 0.9458092207506716.
# [I 2025-10-06 19:09:10,998] Trial 17 finished with value: 0.9397095926436728 and parameters: {'C': 0.11190100332515716, 'solver': 'liblinear', 'tol': 1.604925093516669e-05, 'class_weight': None}. Best is trial 3 with value: 0.9458092207506716.
# [I 2025-10-06 19:09:11,077] Trial 18 finished with value: 0.9458828709470081 and parameters: {'C': 3.661349454690378, 'solver': 'lbfgs', 'tol': 0.00015006302358137487, 'class_weight': None}. Best is trial 18 with value: 0.9458828709470081.
# [I 2025-10-06 19:09:11,142] Trial 19 finished with value: 0.9455619602376005 and parameters: {'C': 16.641934385383966, 'solver': 'lbfgs', 'tol': 0.0011832532459480321, 'class_weight': None}. Best is trial 18 with value: 0.9458828709470081.
# [I 2025-10-06 19:09:11,219] Trial 20 finished with value: 0.9456500809302518 and parameters: {'C': 431.63183264183664, 'solver': 'lbfgs', 'tol': 0.00014247188828629624, 'class_weight': None}. Best is trial 18 with value: 0.9458828709470081.
# [I 2025-10-06 19:09:11,301] Trial 21 finished with value: 0.9457805957688904 and parameters: {'C': 3.8771943985110595, 'solver': 'lbfgs', 'tol': 0.00010585785319639672, 'class_weight': None}. Best is trial 18 with value: 0.9458828709470081.
# [I 2025-10-06 19:09:11,380] Trial 22 finished with value: 0.9422251591744918 and parameters: {'C': 0.14215563547336693, 'solver': 'lbfgs', 'tol': 8.235334175261845e-05, 'class_weight': None}. Best is trial 18 with value: 0.9458828709470081.
# [I 2025-10-06 19:09:11,472] Trial 23 finished with value: 0.9457369393342848 and parameters: {'C': 4.954554966896407, 'solver': 'lbfgs', 'tol': 9.645440652477079e-06, 'class_weight': None}. Best is trial 18 with value: 0.9458828709470081.
# [I 2025-10-06 19:09:11,540] Trial 24 finished with value: 0.9434030367635969 and parameters: {'C': 0.3055552636323787, 'solver': 'lbfgs', 'tol': 0.0010414109972881646, 'class_weight': None}. Best is trial 18 with value: 0.9458828709470081.
# [I 2025-10-06 19:09:11,608] Trial 25 finished with value: 0.93646309566372 and parameters: {'C': 0.030159550048908017, 'solver': 'lbfgs', 'tol': 7.524688205726591e-05, 'class_weight': None}. Best is trial 18 with value: 0.9458828709470081.
# [I 2025-10-06 19:09:11,688] Trial 26 finished with value: 0.9456062530248572 and parameters: {'C': 57.42247020731075, 'solver': 'lbfgs', 'tol': 1.6918129625633398e-05, 'class_weight': None}. Best is trial 18 with value: 0.9458828709470081.
# [I 2025-10-06 19:09:11,760] Trial 27 finished with value: 0.9457806611618702 and parameters: {'C': 5.841136862222799, 'solver': 'lbfgs', 'tol': 0.0007802863538930299, 'class_weight': None}. Best is trial 18 with value: 0.9458828709470081.
# [I 2025-10-06 19:09:11,873] Trial 28 finished with value: 0.9456501598522257 and parameters: {'C': 278.36868814161636, 'solver': 'liblinear', 'tol': 0.0006700891984947635, 'class_weight': None}. Best is trial 18 with value: 0.9458828709470081.
# [I 2025-10-06 19:09:11,939] Trial 29 finished with value: 0.9423013421255538 and parameters: {'C': 27.42938070808912, 'solver': 'newton-cg', 'tol': 0.004548589830394356, 'class_weight': 'balanced'}. Best is trial 18 with value: 0.9458828709470081.
# [I 2025-10-06 19:09:12,042] Trial 30 finished with value: 0.9457227175420296 and parameters: {'C': 8.443716025784958, 'solver': 'newton-cg', 'tol': 5.4247976325391865e-06, 'class_weight': None}. Best is trial 18 with value: 0.9458828709470081.
# [I 2025-10-06 19:09:12,110] Trial 31 finished with value: 0.9455287309125664 and parameters: {'C': 0.9558973049467478, 'solver': 'lbfgs', 'tol': 0.0005486463697426213, 'class_weight': None}. Best is trial 18 with value: 0.9458828709470081.
# [I 2025-10-06 19:09:12,189] Trial 32 finished with value: 0.9458536259519157 and parameters: {'C': 3.912695536057098, 'solver': 'lbfgs', 'tol': 0.00011762049905994784, 'class_weight': None}. Best is trial 18 with value: 0.9458828709470081.
# [I 2025-10-06 19:09:12,271] Trial 33 finished with value: 0.945781107029991 and parameters: {'C': 7.2763041342631025, 'solver': 'lbfgs', 'tol': 4.04401557445264e-05, 'class_weight': None}. Best is trial 18 with value: 0.9458828709470081.
# [I 2025-10-06 19:09:12,348] Trial 34 finished with value: 0.9444278485982697 and parameters: {'C': 0.3486679877298332, 'solver': 'lbfgs', 'tol': 3.920884523075457e-05, 'class_weight': None}. Best is trial 18 with value: 0.9458828709470081.
# [I 2025-10-06 19:09:12,429] Trial 35 finished with value: 0.945679441211313 and parameters: {'C': 104.51238473233545, 'solver': 'lbfgs', 'tol': 0.00016115280660586467, 'class_weight': None}. Best is trial 18 with value: 0.9458828709470081.
# [I 2025-10-06 19:09:12,496] Trial 36 finished with value: 0.9369334906755001 and parameters: {'C': 0.03397575906996846, 'solver': 'lbfgs', 'tol': 5.758484621750429e-05, 'class_weight': None}. Best is trial 18 with value: 0.9458828709470081.
# [I 2025-10-06 19:09:12,585] Trial 37 finished with value: 0.9457227869306349 and parameters: {'C': 10.844260336278586, 'solver': 'lbfgs', 'tol': 2.4138082215820494e-05, 'class_weight': None}. Best is trial 18 with value: 0.9458828709470081.
# [I 2025-10-06 19:09:12,678] Trial 38 finished with value: 0.9457942360824028 and parameters: {'C': 2.395662494223229, 'solver': 'newton-cg', 'tol': 9.603629054347033e-06, 'class_weight': 'balanced'}. Best is trial 18 with value: 0.9458828709470081.
# [I 2025-10-06 19:09:12,783] Trial 39 finished with value: 0.9457941881417492 and parameters: {'C': 2.2542520269772144, 'solver': 'newton-cg', 'tol': 3.534046563135614e-06, 'class_weight': 'balanced'}. Best is trial 18 with value: 0.9458828709470081.
# [I 2025-10-06 19:09:12,863] Trial 40 finished with value: 0.9102300364396928 and parameters: {'C': 0.0014211189102331435, 'solver': 'newton-cg', 'tol': 1.0403266343156584e-05, 'class_weight': 'balanced'}. Best is trial 18 with value: 0.9458828709470081.
# [I 2025-10-06 19:09:12,966] Trial 41 finished with value: 0.9458231501559738 and parameters: {'C': 2.1277646753198676, 'solver': 'newton-cg', 'tol': 1.9375157793065834e-06, 'class_weight': 'balanced'}. Best is trial 18 with value: 0.9458828709470081.
# [I 2025-10-06 19:09:13,068] Trial 42 finished with value: 0.9448678293023316 and parameters: {'C': 0.43414259651773485, 'solver': 'newton-cg', 'tol': 1.9936635193779745e-06, 'class_weight': 'balanced'}. Best is trial 18 with value: 0.9458828709470081.
# [I 2025-10-06 19:09:13,158] Trial 43 finished with value: 0.945562112231377 and parameters: {'C': 27.128578201082036, 'solver': 'newton-cg', 'tol': 8.451934339162098e-06, 'class_weight': 'balanced'}. Best is trial 18 with value: 0.9458828709470081.
# [I 2025-10-06 19:09:13,259] Trial 44 finished with value: 0.9457937933300959 and parameters: {'C': 1.9676066440194595, 'solver': 'newton-cg', 'tol': 3.0379026631604227e-06, 'class_weight': 'balanced'}. Best is trial 18 with value: 0.9458828709470081.
# [I 2025-10-06 19:09:13,314] Trial 45 finished with value: 0.8592594759441946 and parameters: {'C': 0.16362665344572705, 'solver': 'newton-cg', 'tol': 0.08042634509742583, 'class_weight': 'balanced'}. Best is trial 18 with value: 0.9458828709470081.
# [I 2025-10-06 19:09:13,404] Trial 46 finished with value: 0.9371098786714179 and parameters: {'C': 0.035098888388403894, 'solver': 'newton-cg', 'tol': 1.0955797617036763e-06, 'class_weight': 'balanced'}. Best is trial 18 with value: 0.9458828709470081.
# [I 2025-10-06 19:09:13,528] Trial 47 finished with value: 0.9457201874448834 and parameters: {'C': 1.5149987777969742, 'solver': 'saga', 'tol': 2.4023134587575134e-05, 'class_weight': 'balanced'}. Best is trial 18 with value: 0.9458828709470081.
# [I 2025-10-06 19:09:13,665] Trial 48 finished with value: 0.9456500987009903 and parameters: {'C': 145.1381722529741, 'solver': 'liblinear', 'tol': 5.711652083641472e-06, 'class_weight': 'balanced'}. Best is trial 18 with value: 0.9458828709470081.
# [I 2025-10-06 19:09:13,796] Trial 49 finished with value: 0.9455913708200402 and parameters: {'C': 19.25572914433451, 'solver': 'saga', 'tol': 2.0584970192196722e-06, 'class_weight': 'balanced'}. Best is trial 18 with value: 0.9458828709470081.

# %%
print('Best trial:')
trial = study_logistic.best_trial
print('  F1-score: {}'.format(trial.value))
print('  Params: ')
for key, value in trial.params.items():
    print('    {}: {}'.format(key, value))
    
best_model_logistic = LogisticRegression(**study_logistic.best_params)
best_model_logistic.fit(X_train_smt, y_train_smt)

# Evaluate on the test set
y_pred = best_model_logistic.predict(X_test_encoded)

report = classification_report(y_test, y_pred)
print(report)
# Out:
# Best trial:
#   F1-score: 0.9458828709470081
#   Params:
#     C: 3.661349454690378
#     solver: lbfgs
#     tol: 0.00015006302358137487
#     class_weight: None
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96     11423
#            1       0.56      0.94      0.70      1074
#
#     accuracy                           0.93     12497
#    macro avg       0.77      0.94      0.83     12497
# weighted avg       0.96      0.93      0.94     12497

# %% [markdown]
# ### Attempt 4
#
# 1. XGBoost
# 1. Handle Class Imbalance Using SMOTE Tomek
# 1. Parameter tunning using optuna

# %%
# Define the objective function for Optuna
def objective(trial):
    param = {
        'objective': 'binary:logistic',
        'eval_metric': 'logloss',
        'verbosity': 0,
        'booster': 'gbtree',
        'lambda': trial.suggest_float('lambda', 1e-3, 10.0, log=True),
        'alpha': trial.suggest_float('alpha', 1e-3, 10.0, log=True),
        'subsample': trial.suggest_float('subsample', 0.4, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.4, 1.0),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'eta': trial.suggest_float('eta', 0.01, 0.3),
        'gamma': trial.suggest_float('gamma', 0, 10),
        'scale_pos_weight': trial.suggest_float('scale_pos_weight', 1, 10),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'max_delta_step': trial.suggest_int('max_delta_step', 0, 10)
    }

    model = XGBClassifier(**param)
    
    # Calculate the cross-validated f1_score
    f1_scorer = make_scorer(f1_score, average='macro')
    scores = cross_val_score(model, X_train_smt, y_train_smt, cv=3, scoring=f1_scorer, n_jobs=-1)
    
    return np.mean(scores)

study_xgb = optuna.create_study(direction='maximize')
study_xgb.optimize(objective, n_trials=50)
# Out:
# [I 2025-10-06 19:09:13,884] A new study created in memory with name: no-name-bd9af1cd-fcec-4bd2-98ab-4ccb5313157c
# [I 2025-10-06 19:09:14,321] Trial 0 finished with value: 0.9717336470394571 and parameters: {'lambda': 0.001181133370346612, 'alpha': 0.002104687137480764, 'subsample': 0.5266130737804245, 'colsample_bytree': 0.9687603810239023, 'max_depth': 9, 'eta': 0.15577229031951093, 'gamma': 0.08966594335556466, 'scale_pos_weight': 6.8702685170899, 'min_child_weight': 6, 'max_delta_step': 2}. Best is trial 0 with value: 0.9717336470394571.
# [I 2025-10-06 19:09:14,587] Trial 1 finished with value: 0.958199446759845 and parameters: {'lambda': 3.986744909941824, 'alpha': 8.494549706577832, 'subsample': 0.6026009922529096, 'colsample_bytree': 0.720982586157897, 'max_depth': 7, 'eta': 0.16699862153158387, 'gamma': 5.241436840195294, 'scale_pos_weight': 8.637929239762515, 'min_child_weight': 8, 'max_delta_step': 2}. Best is trial 0 with value: 0.9717336470394571.
# [I 2025-10-06 19:09:14,787] Trial 2 finished with value: 0.9710111663639092 and parameters: {'lambda': 0.8293229322270923, 'alpha': 3.369955568941448, 'subsample': 0.9684542980162225, 'colsample_bytree': 0.794337943829746, 'max_depth': 7, 'eta': 0.2136444028179713, 'gamma': 4.0707481047082865, 'scale_pos_weight': 1.1918874876640748, 'min_child_weight': 1, 'max_delta_step': 9}. Best is trial 0 with value: 0.9717336470394571.
# [I 2025-10-06 19:09:14,954] Trial 3 finished with value: 0.9531493643592498 and parameters: {'lambda': 0.016291319139274025, 'alpha': 0.4698906143377452, 'subsample': 0.407829064676914, 'colsample_bytree': 0.5009422964223926, 'max_depth': 3, 'eta': 0.20546595164542458, 'gamma': 8.420222757273754, 'scale_pos_weight': 3.192336656633666, 'min_child_weight': 5, 'max_delta_step': 6}. Best is trial 0 with value: 0.9717336470394571.
# [I 2025-10-06 19:09:15,292] Trial 4 finished with value: 0.957848349958995 and parameters: {'lambda': 0.0010810970203686268, 'alpha': 0.01829192869645623, 'subsample': 0.49390516597040574, 'colsample_bytree': 0.7746942683707093, 'max_depth': 8, 'eta': 0.06120042228079815, 'gamma': 0.3600571839914979, 'scale_pos_weight': 7.4181331835432625, 'min_child_weight': 10, 'max_delta_step': 5}. Best is trial 0 with value: 0.9717336470394571.
# [I 2025-10-06 19:09:15,532] Trial 5 finished with value: 0.9713890054262474 and parameters: {'lambda': 0.0036937514550910927, 'alpha': 0.5286302068262081, 'subsample': 0.5248081578770964, 'colsample_bytree': 0.9146652602809058, 'max_depth': 10, 'eta': 0.28552901170785594, 'gamma': 4.095594294928187, 'scale_pos_weight': 2.2997543959150297, 'min_child_weight': 7, 'max_delta_step': 5}. Best is trial 0 with value: 0.9717336470394571.
# [I 2025-10-06 19:09:15,694] Trial 6 finished with value: 0.3333333332383123 and parameters: {'lambda': 0.06832836501357487, 'alpha': 9.375692762200604, 'subsample': 0.8265779619821717, 'colsample_bytree': 0.4187749982356937, 'max_depth': 3, 'eta': 0.015843337118751015, 'gamma': 2.549556988430165, 'scale_pos_weight': 8.61111833091912, 'min_child_weight': 3, 'max_delta_step': 1}. Best is trial 0 with value: 0.9717336470394571.
# [I 2025-10-06 19:09:15,863] Trial 7 finished with value: 0.9530579710421957 and parameters: {'lambda': 0.0014035218977772965, 'alpha': 0.9997491707520282, 'subsample': 0.489620938469516, 'colsample_bytree': 0.9390235416720264, 'max_depth': 3, 'eta': 0.25885785458666516, 'gamma': 1.579984247339612, 'scale_pos_weight': 6.724527872338556, 'min_child_weight': 3, 'max_delta_step': 9}. Best is trial 0 with value: 0.9717336470394571.
# [I 2025-10-06 19:09:16,144] Trial 8 finished with value: 0.963887222279365 and parameters: {'lambda': 0.5247482269540389, 'alpha': 0.07424800320023626, 'subsample': 0.5695586693968728, 'colsample_bytree': 0.46156777306621294, 'max_depth': 9, 'eta': 0.15098953251037311, 'gamma': 4.412452227379618, 'scale_pos_weight': 5.650584745909116, 'min_child_weight': 10, 'max_delta_step': 9}. Best is trial 0 with value: 0.9717336470394571.
# [I 2025-10-06 19:09:16,390] Trial 9 finished with value: 0.9652669297451851 and parameters: {'lambda': 0.5248143469232529, 'alpha': 0.0018332555055911456, 'subsample': 0.6093906385402064, 'colsample_bytree': 0.7059274345625546, 'max_depth': 6, 'eta': 0.23111188519197715, 'gamma': 4.9815493688617885, 'scale_pos_weight': 6.926875571254394, 'min_child_weight': 10, 'max_delta_step': 3}. Best is trial 0 with value: 0.9717336470394571.
# [I 2025-10-06 19:09:16,608] Trial 10 finished with value: 0.953321450267144 and parameters: {'lambda': 0.01614806041399858, 'alpha': 0.001070834780843936, 'subsample': 0.7389837865823126, 'colsample_bytree': 0.5858357128389547, 'max_depth': 5, 'eta': 0.10945055354823677, 'gamma': 9.838560129211256, 'scale_pos_weight': 4.330710750779893, 'min_child_weight': 6, 'max_delta_step': 0}. Best is trial 0 with value: 0.9717336470394571.
# [I 2025-10-06 19:09:16,946] Trial 11 finished with value: 0.9754884385440693 and parameters: {'lambda': 0.00532390520363211, 'alpha': 0.012132567464800442, 'subsample': 0.6880408543309845, 'colsample_bytree': 0.9776721114196398, 'max_depth': 10, 'eta': 0.2992634836428932, 'gamma': 0.044828952759247365, 'scale_pos_weight': 1.3847268294803894, 'min_child_weight': 7, 'max_delta_step': 4}. Best is trial 11 with value: 0.9754884385440693.
# [I 2025-10-06 19:09:17,304] Trial 12 finished with value: 0.9757796132568135 and parameters: {'lambda': 0.008728499270521757, 'alpha': 0.007641333015640001, 'subsample': 0.7117170412680054, 'colsample_bytree': 0.9842492220719451, 'max_depth': 10, 'eta': 0.2960317379215822, 'gamma': 0.03171647791078295, 'scale_pos_weight': 4.541306748184386, 'min_child_weight': 5, 'max_delta_step': 3}. Best is trial 12 with value: 0.9757796132568135.
# [I 2025-10-06 19:09:17,542] Trial 13 finished with value: 0.9749920593865626 and parameters: {'lambda': 0.014962174138857141, 'alpha': 0.01168698355611218, 'subsample': 0.7520466197229085, 'colsample_bytree': 0.8693199993026004, 'max_depth': 10, 'eta': 0.29551642941651934, 'gamma': 1.985410825453418, 'scale_pos_weight': 1.0158036530750014, 'min_child_weight': 4, 'max_delta_step': 4}. Best is trial 12 with value: 0.9757796132568135.
# [I 2025-10-06 19:09:17,737] Trial 14 finished with value: 0.9676607408498487 and parameters: {'lambda': 0.06756302026224037, 'alpha': 0.009599463762326217, 'subsample': 0.8350046592966291, 'colsample_bytree': 0.9904158165176377, 'max_depth': 9, 'eta': 0.25592199119115877, 'gamma': 7.086655446886899, 'scale_pos_weight': 4.168217812799765, 'min_child_weight': 8, 'max_delta_step': 7}. Best is trial 12 with value: 0.9757796132568135.
# [I 2025-10-06 19:09:18,060] Trial 15 finished with value: 0.97468295370851 and parameters: {'lambda': 0.003898577654013903, 'alpha': 0.046630890705569694, 'subsample': 0.6728301772694546, 'colsample_bytree': 0.8465117002962997, 'max_depth': 10, 'eta': 0.2909878852982002, 'gamma': 1.1695628972459664, 'scale_pos_weight': 2.6010571269935245, 'min_child_weight': 8, 'max_delta_step': 3}. Best is trial 12 with value: 0.9757796132568135.
# [I 2025-10-06 19:09:18,297] Trial 16 finished with value: 0.970974505495855 and parameters: {'lambda': 0.006136959178027781, 'alpha': 0.004583395309388981, 'subsample': 0.8381428437549827, 'colsample_bytree': 0.6064296530442489, 'max_depth': 8, 'eta': 0.25200378341665314, 'gamma': 2.9725284160395042, 'scale_pos_weight': 4.291999105395582, 'min_child_weight': 5, 'max_delta_step': 7}. Best is trial 12 with value: 0.9757796132568135.
# [I 2025-10-06 19:09:18,512] Trial 17 finished with value: 0.9652846447504672 and parameters: {'lambda': 0.036240339370862636, 'alpha': 0.02141514978407649, 'subsample': 0.6796573581633242, 'colsample_bytree': 0.9993482315921567, 'max_depth': 5, 'eta': 0.19409510571803223, 'gamma': 0.03474001267793706, 'scale_pos_weight': 5.452248155385869, 'min_child_weight': 2, 'max_delta_step': 4}. Best is trial 12 with value: 0.9757796132568135.
# [I 2025-10-06 19:09:18,779] Trial 18 finished with value: 0.9691308996772555 and parameters: {'lambda': 0.00860792093920894, 'alpha': 0.17642815205419207, 'subsample': 0.9343727438919063, 'colsample_bytree': 0.8811408320521652, 'max_depth': 8, 'eta': 0.11668621637988844, 'gamma': 6.128752395698695, 'scale_pos_weight': 2.0209420921881196, 'min_child_weight': 7, 'max_delta_step': 1}. Best is trial 12 with value: 0.9757796132568135.
# [I 2025-10-06 19:09:19,037] Trial 19 finished with value: 0.9714849684972761 and parameters: {'lambda': 0.17194673960354703, 'alpha': 0.0062756249335219165, 'subsample': 0.7586860823981272, 'colsample_bytree': 0.8096578127368479, 'max_depth': 10, 'eta': 0.26740103876576765, 'gamma': 3.0002016374288494, 'scale_pos_weight': 9.563910077382285, 'min_child_weight': 4, 'max_delta_step': 6}. Best is trial 12 with value: 0.9757796132568135.
# [I 2025-10-06 19:09:19,354] Trial 20 finished with value: 0.973671537866359 and parameters: {'lambda': 0.0027029708834010423, 'alpha': 0.03903275218001796, 'subsample': 0.6506025438254276, 'colsample_bytree': 0.6278410467255371, 'max_depth': 9, 'eta': 0.23142857433559386, 'gamma': 0.921016572305894, 'scale_pos_weight': 3.4155635934419073, 'min_child_weight': 7, 'max_delta_step': 3}. Best is trial 12 with value: 0.9757796132568135.
# [I 2025-10-06 19:09:19,594] Trial 21 finished with value: 0.97500585148509 and parameters: {'lambda': 0.017585813716938344, 'alpha': 0.013027113728659443, 'subsample': 0.7598498807356534, 'colsample_bytree': 0.8898796928112227, 'max_depth': 10, 'eta': 0.29407354386365003, 'gamma': 1.9510244499609704, 'scale_pos_weight': 1.3548661868702294, 'min_child_weight': 4, 'max_delta_step': 4}. Best is trial 12 with value: 0.9757796132568135.
# [I 2025-10-06 19:09:19,831] Trial 22 finished with value: 0.9752975716133685 and parameters: {'lambda': 0.029602583261248077, 'alpha': 0.004046328211483009, 'subsample': 0.779673337172145, 'colsample_bytree': 0.9220059745096589, 'max_depth': 10, 'eta': 0.294601902906453, 'gamma': 1.8896200124347053, 'scale_pos_weight': 1.8071378834721703, 'min_child_weight': 4, 'max_delta_step': 4}. Best is trial 12 with value: 0.9757796132568135.
# [I 2025-10-06 19:09:20,247] Trial 23 finished with value: 0.9750917980222029 and parameters: {'lambda': 0.030941717888118638, 'alpha': 0.003517559070302319, 'subsample': 0.9005570744603206, 'colsample_bytree': 0.9388730700209613, 'max_depth': 9, 'eta': 0.27259641960626874, 'gamma': 0.8320905634762826, 'scale_pos_weight': 3.2269683984949595, 'min_child_weight': 5, 'max_delta_step': 5}. Best is trial 12 with value: 0.9757796132568135.
# [I 2025-10-06 19:09:20,526] Trial 24 finished with value: 0.974961412768646 and parameters: {'lambda': 0.19531309643665043, 'alpha': 0.0040287532725092655, 'subsample': 0.7179639319175251, 'colsample_bytree': 0.9396721938930629, 'max_depth': 8, 'eta': 0.2484918986757816, 'gamma': 1.0908059539273394, 'scale_pos_weight': 1.9347080232962548, 'min_child_weight': 3, 'max_delta_step': 2}. Best is trial 12 with value: 0.9757796132568135.
# [I 2025-10-06 19:09:20,793] Trial 25 finished with value: 0.9726289742924509 and parameters: {'lambda': 0.007103319426620363, 'alpha': 0.02932184335514664, 'subsample': 0.8017143891355725, 'colsample_bytree': 0.8444124017479475, 'max_depth': 10, 'eta': 0.23271283576713211, 'gamma': 2.4783459566392327, 'scale_pos_weight': 5.263974035307658, 'min_child_weight': 6, 'max_delta_step': 4}. Best is trial 12 with value: 0.9757796132568135.
# [I 2025-10-06 19:09:21,049] Trial 26 finished with value: 0.9722943237490301 and parameters: {'lambda': 0.04093697979122556, 'alpha': 0.14960589673169128, 'subsample': 0.6457814195301628, 'colsample_bytree': 0.9996878516592348, 'max_depth': 9, 'eta': 0.2996799058129881, 'gamma': 3.4336323754520652, 'scale_pos_weight': 3.7263432883949865, 'min_child_weight': 9, 'max_delta_step': 6}. Best is trial 12 with value: 0.9757796132568135.
# [I 2025-10-06 19:09:21,439] Trial 27 finished with value: 0.9768034172398942 and parameters: {'lambda': 0.0025056216655354392, 'alpha': 0.007827246068462378, 'subsample': 0.7884385324297807, 'colsample_bytree': 0.7487435432703637, 'max_depth': 10, 'eta': 0.1863778195987944, 'gamma': 0.0073611821907589026, 'scale_pos_weight': 2.708981510168301, 'min_child_weight': 2, 'max_delta_step': 3}. Best is trial 27 with value: 0.9768034172398942.
# [I 2025-10-06 19:09:21,692] Trial 28 finished with value: 0.9732752433916865 and parameters: {'lambda': 0.002277702365787946, 'alpha': 0.00859012627043402, 'subsample': 0.8715596119954062, 'colsample_bytree': 0.6545273513843939, 'max_depth': 7, 'eta': 0.18695631846081887, 'gamma': 0.5180126699791524, 'scale_pos_weight': 2.827401103615837, 'min_child_weight': 1, 'max_delta_step': 0}. Best is trial 27 with value: 0.9768034172398942.
# [I 2025-10-06 19:09:22,046] Trial 29 finished with value: 0.9705608992234288 and parameters: {'lambda': 0.0016419743961107818, 'alpha': 0.0016056090652497971, 'subsample': 0.6950951862835966, 'colsample_bytree': 0.5608201642919868, 'max_depth': 9, 'eta': 0.13600328047729213, 'gamma': 0.12842747255677356, 'scale_pos_weight': 5.09366833971218, 'min_child_weight': 2, 'max_delta_step': 1}. Best is trial 27 with value: 0.9768034172398942.
# [I 2025-10-06 19:09:22,241] Trial 30 finished with value: 0.9344405391941053 and parameters: {'lambda': 0.004797233019217214, 'alpha': 0.0025156914588544215, 'subsample': 0.715845469789164, 'colsample_bytree': 0.6599094961121266, 'max_depth': 4, 'eta': 0.07662022127107096, 'gamma': 1.3983274548844125, 'scale_pos_weight': 5.959576629849163, 'min_child_weight': 6, 'max_delta_step': 3}. Best is trial 27 with value: 0.9768034172398942.
# [I 2025-10-06 19:09:22,604] Trial 31 finished with value: 0.9770680309148156 and parameters: {'lambda': 0.008946094961511495, 'alpha': 0.006762204806337091, 'subsample': 0.7659624194010324, 'colsample_bytree': 0.9573726738269626, 'max_depth': 10, 'eta': 0.27508158927653986, 'gamma': 0.12900310242766666, 'scale_pos_weight': 1.9050843536741953, 'min_child_weight': 2, 'max_delta_step': 2}. Best is trial 31 with value: 0.9770680309148156.
# [I 2025-10-06 19:09:22,995] Trial 32 finished with value: 0.975705997253275 and parameters: {'lambda': 9.326476232877653, 'alpha': 0.06537636275504184, 'subsample': 0.801774834808819, 'colsample_bytree': 0.9642396694430176, 'max_depth': 10, 'eta': 0.2749846989176372, 'gamma': 0.021609155431964844, 'scale_pos_weight': 2.6665503166009374, 'min_child_weight': 2, 'max_delta_step': 2}. Best is trial 31 with value: 0.9770680309148156.
# [I 2025-10-06 19:09:23,320] Trial 33 finished with value: 0.975150196724555 and parameters: {'lambda': 7.325395207940966, 'alpha': 0.0637237291605493, 'subsample': 0.7944414259989961, 'colsample_bytree': 0.7434976693408224, 'max_depth': 9, 'eta': 0.27495607659139254, 'gamma': 0.6303462078874542, 'scale_pos_weight': 2.6702938876902955, 'min_child_weight': 2, 'max_delta_step': 2}. Best is trial 31 with value: 0.9770680309148156.
# [I 2025-10-06 19:09:23,683] Trial 34 finished with value: 0.9753392110621303 and parameters: {'lambda': 2.2288982754121425, 'alpha': 0.021034916652914296, 'subsample': 0.8675040867022776, 'colsample_bytree': 0.8228966075369707, 'max_depth': 10, 'eta': 0.2125396593501485, 'gamma': 0.704225002171372, 'scale_pos_weight': 4.724786298170205, 'min_child_weight': 1, 'max_delta_step': 2}. Best is trial 31 with value: 0.9770680309148156.
# [I 2025-10-06 19:09:23,924] Trial 35 finished with value: 0.9731426077690747 and parameters: {'lambda': 1.3308716441937478, 'alpha': 0.14449440965237456, 'subsample': 0.990451341796339, 'colsample_bytree': 0.9611001314085441, 'max_depth': 8, 'eta': 0.23457449408276668, 'gamma': 1.33454096967577, 'scale_pos_weight': 3.5757614205892283, 'min_child_weight': 2, 'max_delta_step': 1}. Best is trial 31 with value: 0.9770680309148156.
# [I 2025-10-06 19:09:24,180] Trial 36 finished with value: 0.9714423052389026 and parameters: {'lambda': 0.010019168089346183, 'alpha': 2.77431507758425, 'subsample': 0.927722569168107, 'colsample_bytree': 0.7574147682885299, 'max_depth': 7, 'eta': 0.16967094824878656, 'gamma': 0.02093497288046913, 'scale_pos_weight': 2.870335166599265, 'min_child_weight': 3, 'max_delta_step': 2}. Best is trial 31 with value: 0.9770680309148156.
# [I 2025-10-06 19:09:24,422] Trial 37 finished with value: 0.9674396805341009 and parameters: {'lambda': 3.978093723938017, 'alpha': 0.28231236849897995, 'subsample': 0.8167047561776619, 'colsample_bytree': 0.9023437791562676, 'max_depth': 9, 'eta': 0.18169040763032718, 'gamma': 6.431208827778957, 'scale_pos_weight': 3.973177682666942, 'min_child_weight': 1, 'max_delta_step': 3}. Best is trial 31 with value: 0.9770680309148156.
# [I 2025-10-06 19:09:24,643] Trial 38 finished with value: 0.9743448150016941 and parameters: {'lambda': 0.16354575771232518, 'alpha': 0.007176869414546384, 'subsample': 0.8642017944499838, 'colsample_bytree': 0.9718603134492079, 'max_depth': 10, 'eta': 0.27730027987720374, 'gamma': 2.521496705544944, 'scale_pos_weight': 2.2872690523505126, 'min_child_weight': 2, 'max_delta_step': 0}. Best is trial 31 with value: 0.9770680309148156.
# [I 2025-10-06 19:09:24,888] Trial 39 finished with value: 0.9729995514785464 and parameters: {'lambda': 0.002438325857053402, 'alpha': 0.03141460132985162, 'subsample': 0.5987842115064697, 'colsample_bytree': 0.5425962571290213, 'max_depth': 6, 'eta': 0.21643890807484795, 'gamma': 0.5195921433972993, 'scale_pos_weight': 1.6111053391875942, 'min_child_weight': 1, 'max_delta_step': 1}. Best is trial 31 with value: 0.9770680309148156.
# [I 2025-10-06 19:09:25,167] Trial 40 finished with value: 0.973890071593006 and parameters: {'lambda': 0.0011205054520149402, 'alpha': 0.002558500497129924, 'subsample': 0.732482149926238, 'colsample_bytree': 0.784628215118958, 'max_depth': 8, 'eta': 0.24145236414631152, 'gamma': 1.7352275701035145, 'scale_pos_weight': 4.673343377397512, 'min_child_weight': 3, 'max_delta_step': 2}. Best is trial 31 with value: 0.9770680309148156.
# [I 2025-10-06 19:09:25,505] Trial 41 finished with value: 0.976220173457434 and parameters: {'lambda': 0.011376022420265027, 'alpha': 0.016717783161773192, 'subsample': 0.7746846926105608, 'colsample_bytree': 0.9478514691879507, 'max_depth': 10, 'eta': 0.2688633836245056, 'gamma': 0.07484498063550599, 'scale_pos_weight': 1.2620457741442102, 'min_child_weight': 7, 'max_delta_step': 3}. Best is trial 31 with value: 0.9770680309148156.
# [I 2025-10-06 19:09:25,834] Trial 42 finished with value: 0.9754434972918932 and parameters: {'lambda': 0.011433808278987549, 'alpha': 0.017804498643189868, 'subsample': 0.7850313401866319, 'colsample_bytree': 0.9494538403905302, 'max_depth': 10, 'eta': 0.26408153421540453, 'gamma': 0.488257847271636, 'scale_pos_weight': 2.269329950054119, 'min_child_weight': 9, 'max_delta_step': 3}. Best is trial 31 with value: 0.9770680309148156.
# [I 2025-10-06 19:09:26,117] Trial 43 finished with value: 0.9755897125850933 and parameters: {'lambda': 0.021264803077667066, 'alpha': 0.00583771589866699, 'subsample': 0.784808400970607, 'colsample_bytree': 0.9102927720579566, 'max_depth': 9, 'eta': 0.2752776413421635, 'gamma': 0.9507254821888073, 'scale_pos_weight': 2.9887144696987074, 'min_child_weight': 3, 'max_delta_step': 3}. Best is trial 31 with value: 0.9770680309148156.
# [I 2025-10-06 19:09:26,304] Trial 44 finished with value: 0.9689782856842015 and parameters: {'lambda': 0.0811975984304711, 'alpha': 0.07258322814406666, 'subsample': 0.7658035510311262, 'colsample_bytree': 0.8706617310884971, 'max_depth': 10, 'eta': 0.2799713277838411, 'gamma': 8.356235675009263, 'scale_pos_weight': 1.152254343849532, 'min_child_weight': 2, 'max_delta_step': 2}. Best is trial 31 with value: 0.9770680309148156.
# [I 2025-10-06 19:09:26,579] Trial 45 finished with value: 0.9756776733320476 and parameters: {'lambda': 0.0035599174423546994, 'alpha': 0.014119436924969845, 'subsample': 0.8425587222273465, 'colsample_bytree': 0.9616492292509631, 'max_depth': 10, 'eta': 0.22037000471321982, 'gamma': 1.4721757969149074, 'scale_pos_weight': 1.6084838945177853, 'min_child_weight': 1, 'max_delta_step': 10}. Best is trial 31 with value: 0.9770680309148156.
# [I 2025-10-06 19:09:26,984] Trial 46 finished with value: 0.9508396347685992 and parameters: {'lambda': 0.0017890180159435968, 'alpha': 0.02516275206132051, 'subsample': 0.732740512914092, 'colsample_bytree': 0.9202179525536869, 'max_depth': 9, 'eta': 0.019045115165382542, 'gamma': 0.36820797440724307, 'scale_pos_weight': 2.298843369405919, 'min_child_weight': 5, 'max_delta_step': 1}. Best is trial 31 with value: 0.9770680309148156.
# [I 2025-10-06 19:09:27,328] Trial 47 finished with value: 0.9717494907423037 and parameters: {'lambda': 0.012290563127542984, 'alpha': 0.053741044301182206, 'subsample': 0.4150188382265667, 'colsample_bytree': 0.8441375045116756, 'max_depth': 10, 'eta': 0.20106037030291452, 'gamma': 2.089442460605978, 'scale_pos_weight': 5.992872778012602, 'min_child_weight': 8, 'max_delta_step': 5}. Best is trial 31 with value: 0.9770680309148156.
# [I 2025-10-06 19:09:27,668] Trial 48 finished with value: 0.97189903840348 and parameters: {'lambda': 0.30959963752847924, 'alpha': 0.0012857173606256064, 'subsample': 0.6476651977694331, 'colsample_bytree': 0.4223677141242084, 'max_depth': 9, 'eta': 0.2553785136076005, 'gamma': 0.004892859907660391, 'scale_pos_weight': 8.177884093215784, 'min_child_weight': 2, 'max_delta_step': 2}. Best is trial 31 with value: 0.9770680309148156.
# [I 2025-10-06 19:09:27,900] Trial 49 finished with value: 0.9727336110006245 and parameters: {'lambda': 0.04642901870024267, 'alpha': 0.008783152516335085, 'subsample': 0.806269809443531, 'colsample_bytree': 0.9731919525694684, 'max_depth': 10, 'eta': 0.2452529455060808, 'gamma': 3.736087192755655, 'scale_pos_weight': 2.548489392146073, 'min_child_weight': 3, 'max_delta_step': 3}. Best is trial 31 with value: 0.9770680309148156.

# %%
print('Best trial:')
trial = study_xgb.best_trial
print('  F1-score: {}'.format(trial.value))
print('  Params: ')
for key, value in trial.params.items():
    print('    {}: {}'.format(key, value))
    
best_params = study_xgb.best_params
best_model_xgb = XGBClassifier(**best_params)
best_model_xgb.fit(X_train_smt, y_train_smt)

# Evaluate on the test set
y_pred = best_model_xgb.predict(X_test_encoded)

report = classification_report(y_test, y_pred)
print(report)
# Out:
# Best trial:
#   F1-score: 0.9770680309148156
#   Params:
#     lambda: 0.008946094961511495
#     alpha: 0.006762204806337091
#     subsample: 0.7659624194010324
#     colsample_bytree: 0.9573726738269626
#     max_depth: 10
#     eta: 0.27508158927653986
#     gamma: 0.12900310242766666
#     scale_pos_weight: 1.9050843536741953
#     min_child_weight: 2
#     max_delta_step: 2
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98     11423
#            1       0.73      0.84      0.78      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.86      0.90      0.88     12497
# weighted avg       0.96      0.96      0.96     12497

# %% [markdown]
# ## Model Evaluation : ROC/AUC

# %%
y_pred = best_model_logistic.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96     11423
#            1       0.56      0.94      0.70      1074
#
#     accuracy                           0.93     12497
#    macro avg       0.77      0.94      0.83     12497
# weighted avg       0.96      0.93      0.94     12497

# %%
from sklearn.metrics import roc_curve

probabilities = best_model_logistic.predict_proba(X_test_encoded)[:,1]
fpr, tpr, thresholds = roc_curve(y_test, probabilities)

fpr[:5], tpr[:5], thresholds[:5]
# Out:
# (array([0.        , 0.        , 0.        , 0.00008754, 0.00008754]),
#  array([0.        , 0.0009311 , 0.16108007, 0.16108007, 0.17690875]),
#  array([       inf, 1.        , 0.99942841, 0.99942107, 0.99931763]))

# %%
from sklearn.metrics import auc

area = auc(fpr, tpr)
area
# Out:
# 0.9836683185660083

# %%
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % area)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## Model Evaluation : Rankordering, KS statistic, Gini coeff

# %%
probabilities = best_model_logistic.predict_proba(X_test_encoded)[:,1]

df_eval = pd.DataFrame({
    'Default Truth': y_test,
    'Default Probability': probabilities
})
df_eval.head(3)
# Out:
#        Default Truth  Default Probability
# 19205              0                0.537
# 15514              0                0.000
# 30367              0                0.006

# %%
df_eval['Decile'] = pd.qcut(df_eval['Default Probability'], 10, labels=False, duplicates='drop')
df_eval.head(3)
# Out:
#        Default Truth  Default Probability  Decile
# 19205              0                0.537       8
# 15514              0                0.000       2
# 30367              0                0.006       6

# %%
df_eval[df_eval.Decile==8]['Default Probability'].describe()
# Out:
# count   1250.000
# mean       0.486
# std        0.182
# min        0.214
# 25%        0.318
# 50%        0.469
# 75%        0.642
# max        0.819
# Name: Default Probability, dtype: float64

# %%
df_decile = df_eval.groupby('Decile').apply(lambda x: pd.Series({
    'Minimum Probability': x['Default Probability'].min(),
    'Maximum Probability': x['Default Probability'].max(),
    'Events': x['Default Truth'].sum(),
    'Non-events': x['Default Truth'].count() - x['Default Truth'].sum(),    
}))
df_decile.reset_index(inplace=True)
df_decile
# Out:
# /var/folders/hf/yt2vntbs2cs3zhkmcfyxz58w0000gn/T/ipykernel_45244/4037021561.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_decile = df_eval.groupby('Decile').apply(lambda x: pd.Series({
#    Decile  Minimum Probability  Maximum Probability  Events  Non-events
# 0       0                0.000                0.000   0.000    1250.000
# 1       1                0.000                0.000   0.000    1250.000
# 2       2                0.000                0.000   0.000    1249.000
# 3       3                0.000                0.000   0.000    1250.000
# 4       4                0.000                0.001   0.000    1250.000
# 5       5                0.001                0.004   0.000    1249.000
# 6       6                0.004                0.029   5.000    1245.000
# 7       7                0.029                0.214   9.000    1240.000
# 8       8                0.214                0.819 161.000    1089.000
# 9       9                0.819                1.000 899.000     351.000

# %%
df_decile['Event Rate'] = df_decile['Events']*100 / (df_decile['Events']+df_decile['Non-events'])
df_decile['Non-event Rate'] = df_decile['Non-events']*100 / (df_decile['Events']+df_decile['Non-events'])
df_decile
# Out:
#    Decile  Minimum Probability  Maximum Probability  Events  Non-events  \
# 0       0                0.000                0.000   0.000    1250.000
# 1       1                0.000                0.000   0.000    1250.000
# 2       2                0.000                0.000   0.000    1249.000
# 3       3                0.000                0.000   0.000    1250.000
# 4       4                0.000                0.001   0.000    1250.000
# 5       5                0.001                0.004   0.000    1249.000
# 6       6                0.004                0.029   5.000    1245.000
# 7       7                0.029                0.214   9.000    1240.000
# 8       8                0.214                0.819 161.000    1089.000
# 9       9                0.819                1.000 899.000     351.000
#
#    Event Rate  Non-event Rate
# 0       0.000         100.000
# 1       0.000         100.000
# 2       0.000         100.000
# 3       0.000         100.000
# 4       0.000         100.000
# 5       0.000         100.000
# 6       0.400          99.600
# 7       0.721          99.279
# 8      12.880          87.120
# 9      71.920          28.080

# %%
df_decile = df_decile.sort_values(by='Decile', ascending=False).reset_index(drop=True)
df_decile
# Out:
#    Decile  Minimum Probability  Maximum Probability  Events  Non-events  \
# 0       9                0.819                1.000 899.000     351.000
# 1       8                0.214                0.819 161.000    1089.000
# 2       7                0.029                0.214   9.000    1240.000
# 3       6                0.004                0.029   5.000    1245.000
# 4       5                0.001                0.004   0.000    1249.000
# 5       4                0.000                0.001   0.000    1250.000
# 6       3                0.000                0.000   0.000    1250.000
# 7       2                0.000                0.000   0.000    1249.000
# 8       1                0.000                0.000   0.000    1250.000
# 9       0                0.000                0.000   0.000    1250.000
#
#    Event Rate  Non-event Rate
# 0      71.920          28.080
# 1      12.880          87.120
# 2       0.721          99.279
# 3       0.400          99.600
# 4       0.000         100.000
# 5       0.000         100.000
# 6       0.000         100.000
# 7       0.000         100.000
# 8       0.000         100.000
# 9       0.000         100.000

# %%
df_decile['Cum Events'] =  df_decile['Events'].cumsum()
df_decile['Cum Non-events'] =  df_decile['Non-events'].cumsum()
df_decile
# Out:
#    Decile  Minimum Probability  Maximum Probability  Events  Non-events  \
# 0       9                0.819                1.000 899.000     351.000
# 1       8                0.214                0.819 161.000    1089.000
# 2       7                0.029                0.214   9.000    1240.000
# 3       6                0.004                0.029   5.000    1245.000
# 4       5                0.001                0.004   0.000    1249.000
# 5       4                0.000                0.001   0.000    1250.000
# 6       3                0.000                0.000   0.000    1250.000
# 7       2                0.000                0.000   0.000    1249.000
# 8       1                0.000                0.000   0.000    1250.000
# 9       0                0.000                0.000   0.000    1250.000
#
#    Event Rate  Non-event Rate  Cum Events  Cum Non-events
# 0      71.920          28.080     899.000         351.000
# 1      12.880          87.120    1060.000        1440.000
# 2       0.721          99.279    1069.000        2680.000
# 3       0.400          99.600    1074.000        3925.000
# 4       0.000         100.000    1074.000        5174.000
# 5       0.000         100.000    1074.000        6424.000
# 6       0.000         100.000    1074.000        7674.000
# 7       0.000         100.000    1074.000        8923.000
# 8       0.000         100.000    1074.000       10173.000
# 9       0.000         100.000    1074.000       11423.000

# %%
df_decile['Cum Event Rate'] = df_decile['Cum Events'] * 100 / df_decile['Events'].sum()
df_decile['Cum Non-event Rate'] = df_decile['Cum Non-events']*100 / df_decile['Non-events'].sum()
df_decile
# Out:
#    Decile  Minimum Probability  Maximum Probability  Events  Non-events  \
# 0       9                0.819                1.000 899.000     351.000
# 1       8                0.214                0.819 161.000    1089.000
# 2       7                0.029                0.214   9.000    1240.000
# 3       6                0.004                0.029   5.000    1245.000
# 4       5                0.001                0.004   0.000    1249.000
# 5       4                0.000                0.001   0.000    1250.000
# 6       3                0.000                0.000   0.000    1250.000
# 7       2                0.000                0.000   0.000    1249.000
# 8       1                0.000                0.000   0.000    1250.000
# 9       0                0.000                0.000   0.000    1250.000
#
#    Event Rate  Non-event Rate  Cum Events  Cum Non-events  Cum Event Rate  \
# 0      71.920          28.080     899.000         351.000          83.706
# 1      12.880          87.120    1060.000        1440.000          98.696
# 2       0.721          99.279    1069.000        2680.000          99.534
# 3       0.400          99.600    1074.000        3925.000         100.000
# 4       0.000         100.000    1074.000        5174.000         100.000
# 5       0.000         100.000    1074.000        6424.000         100.000
# 6       0.000         100.000    1074.000        7674.000         100.000
# 7       0.000         100.000    1074.000        8923.000         100.000
# 8       0.000         100.000    1074.000       10173.000         100.000
# 9       0.000         100.000    1074.000       11423.000         100.000
#
#    Cum Non-event Rate
# 0               3.073
# 1              12.606
# 2              23.461
# 3              34.361
# 4              45.295
# 5              56.237
# 6              67.180
# 7              78.114
# 8              89.057
# 9             100.000

# %%
df_decile['KS'] = abs(df_decile['Cum Event Rate'] - df_decile['Cum Non-event Rate'])
df_decile
# Out:
#    Decile  Minimum Probability  Maximum Probability  Events  Non-events  \
# 0       9                0.819                1.000 899.000     351.000
# 1       8                0.214                0.819 161.000    1089.000
# 2       7                0.029                0.214   9.000    1240.000
# 3       6                0.004                0.029   5.000    1245.000
# 4       5                0.001                0.004   0.000    1249.000
# 5       4                0.000                0.001   0.000    1250.000
# 6       3                0.000                0.000   0.000    1250.000
# 7       2                0.000                0.000   0.000    1249.000
# 8       1                0.000                0.000   0.000    1250.000
# 9       0                0.000                0.000   0.000    1250.000
#
#    Event Rate  Non-event Rate  Cum Events  Cum Non-events  Cum Event Rate  \
# 0      71.920          28.080     899.000         351.000          83.706
# 1      12.880          87.120    1060.000        1440.000          98.696
# 2       0.721          99.279    1069.000        2680.000          99.534
# 3       0.400          99.600    1074.000        3925.000         100.000
# 4       0.000         100.000    1074.000        5174.000         100.000
# 5       0.000         100.000    1074.000        6424.000         100.000
# 6       0.000         100.000    1074.000        7674.000         100.000
# 7       0.000         100.000    1074.000        8923.000         100.000
# 8       0.000         100.000    1074.000       10173.000         100.000
# 9       0.000         100.000    1074.000       11423.000         100.000
#
#    Cum Non-event Rate     KS
# 0               3.073 80.633
# 1              12.606 86.090
# 2              23.461 76.073
# 3              34.361 65.639
# 4              45.295 54.705
# 5              56.237 43.763
# 6              67.180 32.820
# 7              78.114 21.886
# 8              89.057 10.943
# 9             100.000  0.000

# %% [markdown]
# To assess whether rank ordering is followed, we should look at whether higher deciles (those with higher predicted probabilities) have higher event rates compared to lower deciles. Rank ordering means that as you move from the top decile to the bottom decile, the event rate should generally decrease.
#
# Non-Events - termed as good (customers) who do not default. Events - termed as bad (customers) who default.
#
# Events and Non-Events terms are interchanged based on usecase to usecase.
#
# eg: for marketing usecase, which customer to reach out (who will take loan based on offers) will be events - here it will termed as good, and the customers who will not take loans will be non-events (bad).
#
# **Insights from the Decile Table**
#
# 1. Top Deciles
#
# * The first decile (Decile 9) has a high event rate of 72.00% and a non-event rate of 28.00%. This indicates that the model is highly confident in predicting events in this decile.
# * The second decile (Decile 8) also shows a significant event rate of 12.72%, with a cumulative event rate reaching 98.6%.
#
# 2. Middle Deciles:
#
# * Deciles 7 and 6 show a significant drop in event rates
#
# 3. Lower Deciles:
#
# * Deciles 5 to 0 show zero events, with all predictions being non-events. These deciles collectively have a non-event rate of 100%.
#
# 4. KS Statistic:
#
# * The KS statistic, which is the maximum difference between cumulative event rates and cumulative non-event rates, is highest at Decile 8 with a value of 85.98%. This suggests that the model performs best at distinguishing between events and non-events up to this decile.
#
# * The KS value gradually decreases in the following deciles, indicating a decrease in model performance for distinguishing between events and non-events.
#
# **KS Value**
#
# The highest KS value is 85.98%, found at Decile 8. This indicates that the model's performance in distinguishing between events and non-events is most significant at this decile. (If KS is in top 3 decile and score above 40, it is considered a good predictive model.)

# %%
gini_coefficient = 2 * area - 1

print("AUC:", area)
print("Gini Coefficient:", gini_coefficient)
# Out:
# AUC: 0.9836683185660083
# Gini Coefficient: 0.9673366371320167

# %% [markdown]
# AUC of 0.98: The model is very good at distinguishing between events and non-events.
#
# Gini coefficient of 0.96: This further confirms that the model is highly effective in its predictions, with almost perfect rank ordering capability.
#
# The Gini coefficient ranges from -1 to 1, where a value closer to 1 signifies a perfect model, 0 indicates a model with no discriminative power, and -1 signifies a perfectly incorrect model.

# %% [markdown]
# #### Finalize The Model and Visualize Feature Importance

# %%
final_model = best_model_logistic

feature_importance = final_model.coef_[0]

# Create a DataFrame for easier handling
coef_df = pd.DataFrame(feature_importance, index=X_train_encoded.columns, columns=['Coefficients'])

# Sort the coefficients for better visualization
coef_df = coef_df.sort_values(by='Coefficients', ascending=True)

# Plotting
plt.figure(figsize=(8, 4))
plt.barh(coef_df.index, coef_df['Coefficients'], color='steelblue')
plt.xlabel('Coefficient Value')
plt.title('Feature Importance in Logistic Regression')
plt.show()

# %% [markdown]
# ### Save the Model

# %%
X_test_encoded.head(2)
# Out:
#         age  loan_tenure_months  number_of_open_accounts  \
# 19205 0.346               0.755                    0.333
# 15514 0.481               0.226                    1.000
#
#        credit_utilization_ratio  loan_to_income  delinquency_ratio  \
# 19205                     0.990           0.550              0.000
# 15514                     0.323           0.220              0.000
#
#        avg_dpd_per_delinquency  residence_type_Owned  residence_type_Rented  \
# 19205                    0.000                  True                  False
# 15514                    0.000                  True                  False
#
#        loan_purpose_Education  loan_purpose_Home  loan_purpose_Personal  \
# 19205                   False               True                  False
# 15514                    True              False                  False
#
#        loan_type_Unsecured
# 19205                False
# 15514                False

# %%
X_test_encoded.columns
# Out:
# Index(['age', 'loan_tenure_months', 'number_of_open_accounts',
#        'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency', 'residence_type_Owned',
#        'residence_type_Rented', 'loan_purpose_Education', 'loan_purpose_Home',
#        'loan_purpose_Personal', 'loan_type_Unsecured'],
#       dtype='object')

# %%
cols_to_scale
# Out:
# Index(['age', 'number_of_dependants', 'years_at_current_address', 'zipcode',
#        'sanction_amount', 'processing_fee', 'gst', 'net_disbursement',
#        'loan_tenure_months', 'principal_outstanding',
#        'bank_balance_at_application', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
X_train_encoded.columns
# Out:
# Index(['age', 'loan_tenure_months', 'number_of_open_accounts',
#        'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency', 'residence_type_Owned',
#        'residence_type_Rented', 'loan_purpose_Education', 'loan_purpose_Home',
#        'loan_purpose_Personal', 'loan_type_Unsecured'],
#       dtype='object')

# %%
from joblib import dump

model_data = {
    'model': final_model,
    'features': X_train_encoded.columns,
    'scaler': scaler,
    'cols_to_scale': cols_to_scale
}
dump(model_data, 'artifacts/model_data.joblib')
# Out:
# ['artifacts/model_data.joblib']

# %%
final_model.coef_, final_model.intercept_
# Out:
# (array([[-0.03933933,  0.68734259,  1.18029747, 15.92648009, 17.40622399,
#          13.7248741 ,  2.03008363, -1.83853916,  1.8421257 ,  0.96769314,
#          -3.48924867,  1.05558587,  1.05558587]]),
#  array([-20.7663696]))
# Exception ignored in: <function ResourceTracker.__del__ at 0x10ef21f80>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x11a515f80>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x121081f80>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x105141f80>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x105345f80>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x102b91f80>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x10a86df80>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x10a681f80>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x106b05f80>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x10bdc9f80>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x109121f80>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x110021f80>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x1134b9f80>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x111f21f80>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
